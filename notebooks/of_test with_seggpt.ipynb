# %%
# %cd OneFormer/
import numpy as np
import cv2
import torch
import cv2
import imutils

import sys, os, distutils.core
# !git clone 'https://github.com/facebookresearch/detectron2'
dist = distutils.core.run_setup("./detectron2/setup.py")
# !python -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])} --quiet
sys.path.insert(0, os.path.abspath('./detectron2'))

# %% [markdown]
# # Detectron Import

# %%
######
#@title 3. Import Libraries and other Utilities
######
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
setup_logger(name="oneformer")

# Import libraries
import numpy as np
import cv2
import torch
import cv2
import imutils

# Import detectron2 utilities
from detectron2.config import get_cfg
from detectron2.projects.deeplab import add_deeplab_config
from detectron2.data import MetadataCatalog
from demo.defaults import DefaultPredictor
from demo.visualizer import Visualizer, ColorMode


# import OneFormer Project
from oneformer import (
    add_oneformer_config,
    add_common_config,
    add_swin_config,
    add_dinat_config,
    add_convnext_config,
)

######
#@title 4. Define helper functions
######
cpu_device = torch.device("cpu")
SWIN_CFG_DICT = {"cityscapes": "configs/cityscapes/oneformer_swin_large_IN21k_384_bs16_90k.yaml",
            "coco": "configs/coco/oneformer_swin_large_IN21k_384_bs16_100ep.yaml",
            "ade20k": "configs/ade20k/oneformer_swin_large_IN21k_384_bs16_160k.yaml",}

DINAT_CFG_DICT = {"cityscapes": "configs/cityscapes/oneformer_dinat_large_bs16_90k.yaml",
            "coco": "configs/coco/oneformer_dinat_large_bs16_100ep.yaml",
            "ade20k": "configs/ade20k/oneformer_dinat_large_IN21k_384_bs16_160k.yaml",}

def setup_cfg(dataset, model_path, use_swin):
    # load config from file and command-line arguments
    cfg = get_cfg()
    add_deeplab_config(cfg)
    add_common_config(cfg)
    add_swin_config(cfg)
    add_dinat_config(cfg)
    add_convnext_config(cfg)
    add_oneformer_config(cfg)
    if use_swin:
      cfg_path = SWIN_CFG_DICT[dataset]
    else:
      cfg_path = DINAT_CFG_DICT[dataset]
    cfg.merge_from_file(cfg_path)
    cfg.MODEL.DEVICE = 'cuda:0'
    cfg.MODEL.WEIGHTS = model_path
    cfg.freeze()
    return cfg

def setup_modules(dataset, model_path, use_swin):
    cfg = setup_cfg(dataset, model_path, use_swin)
    predictor = DefaultPredictor(cfg)
    metadata = MetadataCatalog.get(
        cfg.DATASETS.TEST_PANOPTIC[0] if len(cfg.DATASETS.TEST_PANOPTIC) else "__unused"
    )
    if 'cityscapes_fine_sem_seg_val' in cfg.DATASETS.TEST_PANOPTIC[0]:
        from cityscapesscripts.helpers.labels import labels
        stuff_colors = [k.color for k in labels if k.trainId != 255]
        metadata = metadata.set(stuff_colors=stuff_colors)

    return predictor, metadata

def panoptic_run(img, predictor, metadata):
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, instance_mode=ColorMode.IMAGE)
    predictions = predictor(img, "panoptic")
    panoptic_seg, segments_info = predictions["panoptic_seg"]
    out = visualizer.draw_panoptic_seg_predictions(
    panoptic_seg.to(cpu_device), segments_info, alpha=0.5
)
    return out

def instance_run(img, predictor, metadata):
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, instance_mode=ColorMode.IMAGE)
    predictions = predictor(img, "instance")
    instances = predictions["instances"].to(cpu_device)
    out = visualizer.draw_instance_predictions(predictions=instances, alpha=0.5)
    return out

def semantic_run(img, predictor, metadata):
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, instance_mode=ColorMode.IMAGE)
    predictions = predictor(img, "semantic")
    out = visualizer.draw_sem_seg(
        predictions["sem_seg"].argmax(dim=0).to(cpu_device), alpha=0.5
    )
    return out

TASK_INFER = {"panoptic": panoptic_run,
              "instance": instance_run,
              "semantic": semantic_run}

# %% [markdown]
# # Initialize the models

# %%
import os
import subprocess

use_swin = True #@param {type: 'boolean'}

def city():
  """
  Initializes the OneFormer model with either DiNAT-L or Swin-L backbone
  based on the 'use_swin' global variable. Downloads the corresponding
  checkpoint if it doesn't exist.
  """
  global use_swin
  if not use_swin:
    checkpoint_path = "250_16_dinat_l_oneformer_cityscapes_90k.pth"
    checkpoint_url = "https://shi-labs.com/projects/oneformer/cityscapes/250_16_dinat_l_oneformer_cityscapes_90k.pth"
  else:
    checkpoint_path = "250_16_swin_l_oneformer_cityscapes_90k.pth"
    checkpoint_url = "https://shi-labs.com/projects/oneformer/cityscapes/250_16_swin_l_oneformer_cityscapes_90k.pth"

  if not os.path.exists(checkpoint_path):
    print(f"Downloading checkpoint: {checkpoint_path}...")
    subprocess.run(f'wget {checkpoint_url}', shell=True)
    print("Download complete.")
  else:
    print(f"Checkpoint already exists: {checkpoint_path}")

  predictor, metadata = setup_modules("cityscapes", checkpoint_path, use_swin)
  return predictor, metadata

# Example of how to call the function:
predictor, metadata = city()


def ade():
  """
  Initializes the OneFormer model for the ADE20K dataset.
  Downloads the checkpoint if it doesn't exist.
  Assumes success of download and setup.

  Returns:
      tuple: (predictor, metadata) - The initialized predictor and metadata.  May return invalid values if download or setup fails.
  """
  global use_swin
  if not use_swin:
    checkpoint_path = "250_16_dinat_l_oneformer_ade20k_160k.pth"
    checkpoint_url = "https://shi-labs.com/projects/oneformer/ade20k/250_16_dinat_l_oneformer_ade20k_160k.pth"
  else:
    checkpoint_path = "250_16_swin_l_oneformer_ade20k_160k.pth"
    checkpoint_url = "https://shi-labs.com/projects/oneformer/ade20k/250_16_swin_l_oneformer_ade20k_160k.pth"

  if not os.path.exists(checkpoint_path):
    print(f"Downloading checkpoint: {checkpoint_path}...")
    subprocess.run(['wget', checkpoint_url], check=True)
    print("Download complete.")

  predictor, metadata = setup_modules("ade20k", checkpoint_path, use_swin)
  return predictor, metadata


predictor, metadata = ade()



def coco():
  global use_swin
  if not use_swin:
    checkpoint_path = "150_16_dinat_l_oneformer_coco_100ep.pth"
    checkpoint_url = 'wget https://shi-labs.com/projects/oneformer/coco/150_16_dinat_l_oneformer_coco_100ep.pth'
  else:
    checkpoint_path = "150_16_swin_l_oneformer_coco_100ep.pth"
    checkpoint_url = "wget https://shi-labs.com/projects/oneformer/coco/150_16_swin_l_oneformer_coco_100ep.pth"

  if not os.path.exists(checkpoint_path):
    print(f"Downloading checkpoint: {checkpoint_path}...")
    subprocess.run(f'wget {checkpoint_url}', shell=True)
    print("Download complete.")
  else:
    print(f"Checkpoint already exists: {checkpoint_path}")

    predictor, metadata = setup_modules("coco", checkpoint_path, use_swin)
    return predictor, metadata



predictor, metadata = coco()

    # You would use predictor and metadata here.  No error checking.

# Now 'predictor' and 'metadata' are initialized and ready to use.
# Now 'predictor' and 'metadata' are initialized and ready to use.

# %%
predictor, metadata = city()

# %% [markdown]
# # Genarating unsupervised mask

# %% [markdown]
# ## Semantic

# %%
import os
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer, ColorMode

# Define input and output directories
input_dir = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower"
# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/coco"
output_base_dir = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower/out/ade"
# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/ade"


# predictor, metadata = coco()
# predictor, metadata = city()
predictor, metadata = ade()


# Ensure output base directory exists
os.makedirs(output_base_dir, exist_ok=True)
os.makedirs(input_dir, exist_ok=True)

# Get list of image files in input directory
image_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

for img_file in image_files:
    # 1) Load & resize
    img_path = os.path.join(input_dir, img_file)
    img = cv2.imread(img_path)                    # BGR
    img = imutils.resize(img, width=640)

    # 2) Extract base name and make output dir
    image_name = os.path.splitext(img_file)[0]
    output_dir = os.path.join(output_base_dir, image_name, "semantic")
    os.makedirs(output_dir, exist_ok=True)

    # 3) Run predictor
    task = "semantic"
    outputs = predictor(img, task)
    print(f"Predictor returned keys for {img_file}:", outputs.keys())

    # 4) Decode logits → per-pixel class map
    sem_seg_logits = outputs["sem_seg"]
    class_map = sem_seg_logits.detach().cpu().argmax(0).numpy()  # (H, W)

    # 5) Save binary masks and red overlay for each non-background class
    unique_ids = np.unique(class_map)
    class_info = {}
    for class_id in unique_ids:
        if class_id == 0:
            continue
        # Get human-readable name
        class_name = metadata.stuff_classes[class_id] \
                     if hasattr(metadata, "stuff_classes") else f"class_{class_id}"
        class_info[class_id] = class_name

        # Save binary mask
        mask = (class_map == class_id).astype(np.uint8) * 255
        mask_path = os.path.join(output_dir, f"{class_name}_id_{class_id}.png")
        cv2.imwrite(mask_path, mask)

        # Save red overlay visualization
        overlay = img.copy()
        colored_mask = np.zeros_like(img)
        colored_mask[:, :, 2] = mask  # Red channel
        overlay = cv2.addWeighted(overlay, 0.7, colored_mask, 0.3, 0)
        vis_path = os.path.join(output_dir, f"{class_name}_id_{class_id}_vis.jpg")
        cv2.imwrite(vis_path, overlay)

    print(f"Found {len(class_info)} unique segments in {img_file}: {class_info.values()}")

    # 6) Build one nice colored overlay via Detectron2's Visualizer
    viz = Visualizer(
        img[:, :, ::-1],                # convert BGR→RGB for the Visualizer
        metadata=metadata,
        instance_mode=ColorMode.SEGMENTATION
    )
    out_viz = viz.draw_sem_seg(class_map)

    # 7) Extract BGR overlay, convert to RGB for Matplotlib
    overlay_bgr = out_viz.get_image()           # BGR
    overlay_rgb = overlay_bgr[:, :, ::-1]       # → RGB

    # 8) Display with Matplotlib
    plt.figure(figsize=(19, 10))
    plt.imshow(overlay_rgb)
    plt.axis("off")
    plt.show()

    # 9) Save final overlay
    overlay_path = os.path.join(output_base_dir, image_name, f"{image_name}_semantic_overlay.jpg")
    cv2.imwrite(overlay_path, overlay_bgr)
    print(f"Saved colored overlay for {img_file} to {overlay_path}")

# %% [markdown]
# # Instance

# %%
import os
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer, ColorMode

# ─── 1. Define image directory and get all image files ────────────────────────
img_dir = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower/inpt"

# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/coco"

# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/city"
# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/ade"
output_base_dir = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower/out/coco/"

predictor, metadata = coco()
# predictor, metadata = city()
# predictor, metadata = ade()


img_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
assert len(img_files) > 0, f"No images found in {img_dir}"

# ─── 2. Process each image ────────────────────────────────────────────────────
for img_file in img_files:
    img_path = os.path.join(img_dir, img_file)
    img = cv2.imread(img_path)
    assert img is not None, f"Failed to load {img_path}"
    img = imutils.resize(img, width=640)

    # ─── 3. Extract image name and create output directory ────────────────────
    image_name = os.path.splitext(img_file)[0]
    output_dir = os.path.join(output_base_dir, image_name, "instance")
    os.makedirs(output_dir, exist_ok=True)

    # ─── 4. Run instance-segmentation predictor ───────────────────────────────
    task = "instance"
    outputs = predictor(img, task)
    print(f"Predictor returned keys for {img_file}:", outputs.keys())

    # ─── 5. Unpack instance outputs ───────────────────────────────────────────
    instances    = outputs["instances"].to("cpu")
    pred_masks   = instances.pred_masks.numpy()    # (N, H, W)
    pred_classes = instances.pred_classes.numpy()  # (N,)
    scores       = instances.scores.numpy()        # (N,)

    # ─── 6. Save per-instance mask and overlay ────────────────────────────────
    class_info = {}
    for idx, (mask, cid, score) in enumerate(zip(pred_masks, pred_classes, scores)):
        class_name = metadata.thing_classes[cid]
        class_info[cid] = class_name

        # 6a) Save binary mask
        binary_mask = (mask.astype(np.uint8) * 255)
        mask_path = os.path.join(output_dir, f"{class_name}_id{cid}.png")
        cv2.imwrite(mask_path, binary_mask)

        # 6b) Save overlay visualization (red tint)
        overlay = img.copy()
        colored_mask = np.zeros_like(img)
        colored_mask[:, :, 2] = binary_mask
        overlay = cv2.addWeighted(overlay, 0.7, colored_mask, 0.3, 0)
        vis_path = os.path.join(output_dir, f"{class_name}_id_{cid}_vis.jpg")
        cv2.imwrite(vis_path, overlay)

    print(f"Found {len(class_info)} unique classes in {img_file}: {class_info.values()}")

    # ─── 7. Visualize full overlay with all instances ─────────────────────────
    viz = Visualizer(img[:, :, ::-1], metadata=metadata, instance_mode=ColorMode.SEGMENTATION)
    out_viz = viz.draw_instance_predictions(instances)
    overlay_bgr = out_viz.get_image()
    overlay_rgb = overlay_bgr[:, :, ::-1]

    # ─── 8. Show and save combined overlay ────────────────────────────────────
    plt.figure(figsize=(19, 10))
    plt.imshow(overlay_rgb)
    plt.axis("off")
    plt.show()

    combined_path = os.path.join(output_dir, f"{image_name}_instance_overlay.jpg")
    cv2.imwrite(combined_path, overlay_bgr)
    print(f"Saved colored overlay to {combined_path}")

# %% [markdown]
# # Panoptic

# %%
import os
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer, ColorMode

# 1) Define image directory and get all image files
# img_dir = "./seggpt/images/"
img_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/train/images/"
output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/coco"

# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/out/of_mask/city"
# output_base_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/of_mask/ade"

predictor, metadata = coco()
# predictor, metadata = city()
# predictor, metadata = ade()
os.makedirs(output_base_dir, exist_ok=True)



img_files = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

for img_file in img_files:
    # 2) Load & resize
    img_path = os.path.join(img_dir, img_file)
    img = cv2.imread(img_path)
    if img is None:
        print(f"Failed to load image: {img_path}")
        continue
    img = imutils.resize(img, width=640)

    # 3) Extract image name and make output dir
    image_name = os.path.splitext(os.path.basename(img_path))[0]

    output_dir = os.path.join(output_base_dir, image_name, "panoptic")
    os.makedirs(output_dir, exist_ok=True)

    # 4) Run predictor
    task = "panoptic"
    outputs = predictor(img, task)
    print(f"Processing {img_file} - Predictor returned keys:", outputs.keys())

    # 5) Get panoptic map
    panoptic_seg, segments_info = outputs["panoptic_seg"]
    panoptic_np = panoptic_seg.detach().cpu().numpy()
    class_info = {}

    # 6) Save masks and overlays
    for seg in segments_info:
        sid = seg["id"]
        cid = seg["category_id"]
        isthing = seg["isthing"]
        
        # Determine class name based on whether it's a thing or stuff class
        try:
            class_name = metadata.thing_classes[cid] if isthing else metadata.stuff_classes[cid]
        except:
            class_name = f"class_{cid}"
        
        class_info[sid] = class_name

        # Save binary mask
        mask = (panoptic_np == sid).astype(np.uint8) * 255
        mask_path = os.path.join(output_dir, f"{class_name}_id_{cid}.png")
        cv2.imwrite(mask_path, mask)
        # print(f"Saved binary mask to {mask_path}")

        # Save overlay visualization (red tint)
        overlay = img.copy()
        # Create a red mask (BGR format)
        colored_mask = np.zeros_like(img)
        colored_mask[:, :, 2] = mask  # Set red channel to the binary mask
        # Blend the original image with the red mask
        overlay = cv2.addWeighted(overlay, 0.7, colored_mask, 0.3, 0)
        vis_path = os.path.join(output_dir, f"{class_name}_id_{cid}_vis.jpg")
        success = cv2.imwrite(vis_path, overlay)
        # if success:
        #     print(f"Saved red overlay to {vis_path}")
        # else:
        #     print(f"Failed to save red overlay to {vis_path}")

    print(f"Found {len(class_info)} unique segments for {img_file}: {class_info.values()}")

    # 7) Visualize full overlay
    viz = Visualizer(img[:, :, ::-1], metadata=metadata, instance_mode=ColorMode.SEGMENTATION)
    out_viz = viz.draw_panoptic_seg_predictions(panoptic_seg.cpu(), segments_info)
    overlay_bgr = out_viz.get_image()
    overlay_rgb = overlay_bgr[:, :, ::-1]

    # 8) Show and save
    plt.figure(figsize=(19, 10))
    plt.imshow(overlay_rgb)
    plt.axis("off")
    plt.show()

    overlay_path = f"seggpt/masks/{image_name}/{image_name}_panoptic_overlay.jpg"
    cv2.imwrite(overlay_path, overlay_bgr)
    print(f"Saved colored overlay to {overlay_path}")

# %% [markdown]
# # SegGpt Experiment

# %% [markdown]
# ## Without COCO mask

# %%
import torch
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import numpy as np
from transformers import SegGptImageProcessor, SegGptForImageSegmentation
import os
from matplotlib.colors import ListedColormap

# --- 1. Configuration ---
reference_image_path = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower/flower.png"
reference_mask_path = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower/out/coco/flower/semantic/flower_id_88.png"
# coco_image_path = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/n_masks/10.png" # <<< COMMENTED OUT AS REQUESTED

target_image_path = "/home/sabbbir/Documents/of/OneFormer/seggpt/flower/garden.png"
output_mask_filename = f"predicted_mask_{os.path.splitext(os.path.basename(target_image_path))[0]}.png"
output_plot_filename = "segmentation_results.png" # Filename for the combined plot

# --- 2. Setup Model and Device ---
print("Loading model, processor, and setting up device...")
try:
    model_name = "BAAI/seggpt-vit-large"
    processor = SegGptImageProcessor.from_pretrained(model_name)
    model = SegGptForImageSegmentation.from_pretrained(model_name)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    print(f"Using device: {device}")
except Exception as e:
    print(f"Error during model setup: {e}")
    exit()

# --- 3. Load and Prepare Data ---
print("Loading and preparing images...")
# <<< Removed coco_image_path from the check
if not all(os.path.exists(p) for p in [reference_image_path, reference_mask_path, target_image_path]):
    print("Error: One or more input files not found.")
    exit()

reference_image = Image.open(reference_image_path).convert("RGB")
# Load cocomask as grayscale for processing - assuming it's a single-channel mask
# cocomask = Image.open(coco_image_path).convert("L") # <<< COMMENTED OUT: No longer loading cocomask
target_image = Image.open(target_image_path).convert("RGB")
reference_mask = Image.open(reference_mask_path).convert("L") # Ensure mask is grayscale

# Resize mask if needed
if reference_mask.size != reference_image.size:
    print("Resizing reference mask to match reference image...")
    reference_mask = reference_mask.resize(reference_image.size, Image.NEAREST)

# Process inputs for the model
inputs = processor(
    images=[target_image],           # Target image
    prompt_images=[reference_image], # Reference image
    prompt_masks=[reference_mask],   # Reference mask
    return_tensors="pt"
)
inputs = {k: v.to(device) for k, v in inputs.items()}
print("Inputs prepared.")

# --- 4. Run Inference and Post-process ---
print("Running inference...")
pred_mask = None
try:
    with torch.no_grad():
        outputs = model(**inputs)

    print("Post-processing output mask...")
    target_sizes = [target_image.size[::-1]] # (height, width)
    # Get PIL Image mask directly if possible, or tensor
    processed_output = processor.post_process_semantic_segmentation(outputs, target_sizes=target_sizes)
    if isinstance(processed_output, list) and len(processed_output) > 0:
        pred_mask = processed_output[0]
    else:
         print("Warning: Post-processing did not return expected output.")
         # Try accessing the raw predicted masks from the outputs
         if hasattr(outputs, 'pred_masks') and outputs.pred_masks is not None:
             # Assuming batch size 1, select the first mask
             pred_mask_tensor = outputs.pred_masks[0].squeeze(0).cpu() # Remove potential channel dim, move to CPU
             # Convert to PIL Image (assuming binary mask or needs thresholding)
             # You might need to adjust this conversion based on the exact output format
             pred_mask_np_temp = (pred_mask_tensor > 0.5).float().numpy() # Example thresholding
             pred_mask = Image.fromarray((pred_mask_np_temp * 255).astype(np.uint8))

         else:
            print("Error: Could not retrieve predicted mask from model output.")
            pred_mask = None # Ensure pred_mask is None if retrieval fails


    print("Inference and post-processing complete.")

except Exception as e:
    print(f"Error during inference or post-processing: {e}")
    # pred_mask remains None


# --- 5. Prepare Data for Plotting ---
reference_image_np_float = np.array(reference_image).astype(np.float32) / 255.0
# cocomask_np = np.array(cocomask) # Grayscale numpy array # <<< COMMENTED OUT: No longer converting cocomask
reference_mask_np = np.array(reference_mask) # Grayscale numpy array
target_image_np_float = np.array(target_image).astype(np.float32) / 255.0

pred_mask_np = None
if pred_mask is not None:
    if isinstance(pred_mask, torch.Tensor):
        # If fallback tensor was used in step 4, ensure it's processed correctly
        pred_mask_np = (pred_mask > 0.5).float().cpu().numpy().squeeze() # Threshold and convert
    elif isinstance(pred_mask, Image.Image):
        pred_mask_np = np.array(pred_mask.convert('L')) # Convert PIL image to numpy
        # Normalize if needed (e.g., if mask values are 0 and 255)
        if pred_mask_np.max() > 1:
             pred_mask_np = pred_mask_np / 255.0


# --- 6. Create Composite Images for Overlays ---

# Composite for Reference Image + Masks (Middle plot, first row)
composite_ref_masks = reference_image_np_float.copy()
cmap_jet = plt.get_cmap('jet')

# <<< COMMENTED OUT: Block for blending cocomask overlay removed
# Blend cocomask overlay
# if cocomask_np is not None:
#     cocomask_colored_rgb = cmap_jet(cocomask_np / 255.0)[:, :, :3] # Apply colormap, get RGB
#     cocomask_alpha = (cocomask_np > 0).astype(np.float32) * 0.5 # Alpha is 0.5 where mask > 0, 0 otherwise
#     alpha_cocomask = cocomask_alpha[:, :, None] # Add dimension for broadcasting
#     composite_ref_masks = (1 - alpha_cocomask) * composite_ref_masks + alpha_cocomask * cocomask_colored_rgb

# Blend reference_mask overlay (This remains)
if reference_mask_np is not None:
    # Normalize reference mask if it's 0-255
    if reference_mask_np.max() > 1:
        reference_mask_np = reference_mask_np / 255.0

    yellow_color = np.array([1, 1, 0]) # Yellow RGB (1,1,0) for normalized image (0-1)
    reference_mask_alpha = (reference_mask_np > 0).astype(np.float32) * 0.7 # Alpha is 0.7 where mask > 0, 0 otherwise
    reference_mask_overlay_rgb = np.tile(yellow_color[None, None, :], reference_mask_np.shape[:2] + (1,)) # Use shape[:2] for grayscale
    alpha_refmask = reference_mask_alpha[:, :, None] # Add dimension for broadcasting
    composite_ref_masks = (1 - alpha_refmask) * composite_ref_masks + alpha_refmask * reference_mask_overlay_rgb

# Composite for Target Image + Predicted Mask (Third plot, second row)
composite_pred_overlay = target_image_np_float.copy()
if pred_mask_np is not None:
    # Ensure pred_mask_np is normalized (0-1) before colormap
    if pred_mask_np.max() > 1:
         pred_mask_np = pred_mask_np / 255.0

    pred_mask_colored_rgb = cmap_jet(pred_mask_np)[:, :, :3] # Apply colormap
    pred_mask_alpha = (pred_mask_np > 0).astype(np.float32) * 0.5 # Alpha 0.5 for masked areas
    alpha_predmask = pred_mask_alpha[:, :, None] # Add dimension for broadcasting
    composite_pred_overlay = (1 - alpha_predmask) * composite_pred_overlay + alpha_predmask * pred_mask_colored_rgb


# --- 7. Plot Results ---
print("Plotting results...")
fig, axes = plt.subplots(2, 3, figsize=(19, 10)) # Create a 2x3 grid of subplots

# Row 1
axes[0, 0].imshow(reference_image)
axes[0, 0].set_title("Reference Image")
axes[0, 0].axis('off')

# <<< Now only shows reference image + reference mask overlay
axes[0, 1].imshow(np.clip(composite_ref_masks, 0, 1)) # Display composite image
axes[0, 1].set_title("Reference Mask Overlay") # <<< Adjusted title slightly
axes[0, 1].axis('off')

axes[0, 2].imshow(target_image)
axes[0, 2].set_title("Target Image")
axes[0, 2].axis('off')

# Row 2
axes[1, 0].imshow(target_image) # Repeated Target Image as in original structure
axes[1, 0].set_title("Target Image")
axes[1, 0].axis('off')

if pred_mask_np is not None:
    axes[1, 1].imshow(pred_mask_np, cmap='jet') # Standalone predicted mask
    axes[1, 1].set_title("Predicted Mask")
    axes[1, 1].axis('off')
    axes[1, 2].imshow(np.clip(composite_ref_masks, 0, 1)) # Display composite image
    axes[1, 2].imshow(np.clip(composite_pred_overlay, 0, 1)) # Display composite prediction overlay
    axes[1, 2].set_title("Prediction Overlay")
    axes[1, 2].axis('off')
else:
    # Display empty plots or placeholders if prediction failed
    for i in range(1, 3):
        axes[1, i].set_title("Prediction Failed")
        axes[1, i].imshow(np.zeros_like(target_image_np_float)) # Show black image
        axes[1, i].axis('off')


plt.tight_layout()
plt.savefig(output_plot_filename) # Save the combined figure
print(f"Combined plot saved as {output_plot_filename}")

# --- 8. Save Predicted Mask ---
# Save the original predicted mask (PIL Image) if available
if isinstance(pred_mask, Image.Image):
     # Ensure it's saved in a suitable mode (e.g., 'L' for grayscale)
     pred_mask.convert('L').save(output_mask_filename)
     print(f"Predicted mask saved as {output_mask_filename}")
elif pred_mask_np is not None:
    # Save the numpy mask as an image (grayscale PNG)
    # Ensure values are 0-255 and uint8 type
    pred_mask_img_to_save = Image.fromarray((pred_mask_np * 255).astype(np.uint8), mode='L')
    pred_mask_img_to_save.save(output_mask_filename)
    print(f"Predicted mask saved as {output_mask_filename}")
else:
     print("Predicted mask could not be saved (prediction failed or unavailable).")
print("Script finished.")

# %%
import torch
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import numpy as np
from transformers import SegGptImageProcessor, SegGptForImageSegmentation
import os
from matplotlib.colors import ListedColormap
import glob # To find image files

# --- 1. Configuration ---
reference_image_path = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/n_images/10.jpg"
reference_mask_path = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/of_mask/coco/10/semantic/sports ball_id_32.png"
# This COCO mask seems to be only for visualization on the reference image, not model input
coco_image_path = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/n_masks/10.png"
# coco_path_for_target_image = ""
# Directory containing target images
target_image_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/n_images"
# Directory to save output plots and masks
output_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/tt/seggpt_output_ball"

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)
print(f"Output will be saved to: {output_dir}")

# --- 2. Setup Model and Device ---
print("Loading model, processor, and setting up device...")
try:
    model_name = "BAAI/seggpt-vit-large"
    processor = SegGptImageProcessor.from_pretrained(model_name)
    model = SegGptForImageSegmentation.from_pretrained(model_name)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    print(f"Using device: {device}")
except Exception as e:
    print(f"Error during model setup: {e}")
    exit()

# --- 3. Load and Prepare Reference Data (Done once) ---
print("Loading and preparing reference data...")
if not all(os.path.exists(p) for p in [reference_image_path, reference_mask_path, coco_image_path]):
    print("Error: One or more reference/coco files not found.")
    exit()

try:
    reference_image = Image.open(reference_image_path).convert("RGB")
    reference_mask = Image.open(reference_mask_path).convert("L") # Ensure mask is grayscale
    cocomask = Image.open(coco_image_path).convert("L") # Load cocomask as grayscale

    # Resize reference mask if needed
    if reference_mask.size != reference_image.size:
        print("Resizing reference mask to match reference image...")
        reference_mask = reference_mask.resize(reference_image.size, Image.NEAREST)

    # Prepare reference data for plotting (done once)
    reference_image_np_float = np.array(reference_image).astype(np.float32) / 255.0
    cocomask_np = np.array(cocomask) # Grayscale numpy array
    reference_mask_np = np.array(reference_mask) # Grayscale numpy array

    # Prepare composite overlay for reference image (done once)
    composite_ref_masks = reference_image_np_float.copy()
    cmap_jet = plt.get_cmap('jet')

    # Blend cocomask overlay
    if cocomask_np is not None:
        cocomask_colored_rgb = cmap_jet(cocomask_np / 255.0)[:, :, :3] # Apply colormap, get RGB
        cocomask_alpha = (cocomask_np > 0).astype(np.float32) * 0.5 # Alpha is 0.5 where mask > 0, 0 otherwise
        alpha_cocomask = cocomask_alpha[:, :, None] # Add dimension for broadcasting
        composite_ref_masks = (1 - alpha_cocomask) * composite_ref_masks + alpha_cocomask * cocomask_colored_rgb

    # Blend reference_mask overlay
    if reference_mask_np is not None:
        yellow_color = np.array([1, 1, 0]) # Yellow RGB (1,1,0) for normalized image (0-1)
        reference_mask_alpha = (reference_mask_np > 0).astype(np.float32) * 0.7 # Alpha is 0.7 where mask > 0, 0 otherwise
        reference_mask_overlay_rgb = np.tile(yellow_color[None, None, :], reference_mask_np.shape + (1,))
        alpha_refmask = reference_mask_alpha[:, :, None] # Add dimension for broadcasting
        composite_ref_masks = (1 - alpha_refmask) * composite_ref_masks + alpha_refmask * reference_mask_overlay_rgb

    print("Reference data prepared.")

except Exception as e:
    print(f"Error loading or preparing reference data: {e}")
    exit()


# --- 4. Process Each Target Image in the Directory ---
print(f"Looking for target images in: {target_image_dir}")
# Find image files (adjust extensions if needed)
image_files = glob.glob(os.path.join(target_image_dir, "*.png")) + \
              glob.glob(os.path.join(target_image_dir, "*.jpg")) + \
              glob.glob(os.path.join(target_image_dir, "*.jpeg"))

if not image_files:
    print(f"No image files found in {target_image_dir}")
    exit()

print(f"Found {len(image_files)} target images to process.")

for target_image_path in image_files:
    print("-" * 30)
    print(f"Processing: {os.path.basename(target_image_path)}")

    # Generate output filenames for this specific target image
    base_filename = os.path.splitext(os.path.basename(target_image_path))[0]
    output_mask_filename = os.path.join(output_dir, f"predicted_mask_{base_filename}.png")
    output_plot_filename = os.path.join(output_dir, f"segmentation_results_{base_filename}.png")

    try:
        # --- 4a. Load and Prepare Target Data ---
        target_image = Image.open(target_image_path).convert("RGB")

        # Process inputs for the model
        inputs = processor(
            images=[target_image],           # Current Target image
            prompt_images=[reference_image], # Re-use loaded Reference image
            prompt_masks=[reference_mask],   # Re-use loaded Reference mask
            return_tensors="pt"
        )
        inputs = {k: v.to(device) for k, v in inputs.items()}
        # print("Inputs prepared for current target.") # Optional: uncomment for more verbose logging

        # --- 4b. Run Inference and Post-process ---
        # print("Running inference...") # Optional: uncomment
        pred_mask = None # Reset for each image
        try:
            with torch.no_grad():
                outputs = model(**inputs)

            # print("Post-processing output mask...") # Optional: uncomment
            target_sizes = [target_image.size[::-1]] # (height, width)
            # Get PIL Image mask directly if possible, or tensor
            processed_output = processor.post_process_semantic_segmentation(outputs, target_sizes=target_sizes)

            if isinstance(processed_output, list) and len(processed_output) > 0 and isinstance(processed_output[0], torch.Tensor):
                 # If output is a tensor, convert it to PIL for consistency
                 pred_mask_tensor = processed_output[0].cpu()
                 pred_mask = Image.fromarray(pred_mask_tensor.squeeze().numpy().astype(np.uint8) * 255, mode='L') # Assuming binary mask, scale to 0-255
            elif isinstance(processed_output, list) and len(processed_output) > 0 and isinstance(processed_output[0], Image.Image):
                 # If output is already a PIL Image
                 pred_mask = processed_output[0].convert('L') # Ensure grayscale
            else:
                print("Warning: Post-processing did not return expected output format. Trying fallback.")
                # Fallback to raw tensor output if post_process fails unexpectedly
                if hasattr(outputs, 'pred_masks') and outputs.pred_masks is not None:
                    pred_mask_tensor = outputs.pred_masks.squeeze().cpu() # Remove batch and channel if present
                    # Thresholding might be needed depending on raw output
                    pred_mask_np_interim = (pred_mask_tensor.numpy() > 0.5).astype(np.uint8) * 255
                    pred_mask = Image.fromarray(pred_mask_np_interim, mode='L')
                else:
                    print("Error: Could not extract predicted mask from model output.")
                    pred_mask = None # Ensure it's None

            # print("Inference and post-processing complete.") # Optional: uncomment

        except Exception as e:
            print(f"Error during inference or post-processing for {os.path.basename(target_image_path)}: {e}")
            pred_mask = None # Ensure pred_mask is None if error occurs

        # --- 4c. Prepare Data for Plotting ---
        target_image_np_float = np.array(target_image).astype(np.float32) / 255.0
        pred_mask_np = None
        if pred_mask is not None:
            pred_mask_np = np.array(pred_mask) # Already L mode (grayscale 0-255)

        # --- 4d. Create Composite Overlay for Prediction ---
        composite_pred_overlay = target_image_np_float.copy()
        if pred_mask_np is not None:
            # Normalize pred_mask_np to 0-1 for colormap
            pred_mask_np_norm = pred_mask_np / 255.0
            pred_mask_colored_rgb = cmap_jet(pred_mask_np_norm)[:, :, :3] # Apply colormap
            pred_mask_alpha = (pred_mask_np > 0).astype(np.float32) * 0.5 # Alpha 0.5 for masked areas
            alpha_predmask = pred_mask_alpha[:, :, None] # Add dimension for broadcasting
            composite_pred_overlay = (1 - alpha_predmask) * composite_pred_overlay + alpha_predmask * pred_mask_colored_rgb

        # --- 4e. Plot Results ---
        fig, axes = plt.subplots(2, 3, figsize=(19, 10)) # Create a 2x3 grid

        # Row 1
        axes[0, 0].imshow(reference_image)
        axes[0, 0].set_title("Reference Image")
        axes[0, 0].axis('off')

        axes[0, 1].imshow(np.clip(composite_ref_masks, 0, 1)) # Display pre-calculated reference composite
        axes[0, 1].set_title("Reference Masks Overlay")
        axes[0, 1].axis('off')

        axes[0, 2].imshow(target_image)
        # axes[0, 2].set_title(f"Target: {os.path.basename(target_image_path)}")
        axes[0, 2].set_title(f"Target Image")

        axes[0, 2].axis('off')

        # Row 2
        axes[1, 0].imshow(target_image) # Repeated Target Image
        # axes[1, 0].set_title(f"Target: {os.path.basename(target_image_path)}")
        axes[1, 0].set_title(f"Target Image")
        axes[1, 0].axis('off')

        if pred_mask_np is not None:
            axes[1, 1].imshow(pred_mask_np, cmap='jet') # Standalone predicted mask (use grayscale map maybe?)
            axes[1, 1].set_title("Predicted Mask")
            axes[1, 1].axis('off')
            axes[1, 2].imshow(np.clip(composite_ref_masks, 0, 1)) # Display composite image

            axes[1, 2].imshow(np.clip(composite_pred_overlay, 0, 1)) # Display composite prediction overlay
            axes[1, 2].set_title("Prediction Overlay")
            axes[1, 2].axis('off')
        else:
            # Handle case where prediction failed
            for i in range(1, 3):
                axes[1, i].text(0.5, 0.5, 'Prediction Failed', horizontalalignment='center', verticalalignment='center', transform=axes[1, i].transAxes)
                axes[1, i].set_title("Prediction Failed")
                axes[1, i].axis('off')


        plt.tight_layout()
        plt.savefig(output_plot_filename) # Save the combined figure for this image
        plt.close(fig) # Close the figure to free memory
        print(f"Saved plot: {output_plot_filename}")

        # --- 4f. Save Predicted Mask ---
        if pred_mask is not None: # pred_mask should be a PIL Image here
            pred_mask.save(output_mask_filename)
            print(f"Saved mask: {output_mask_filename}")
        else:
            print(f"Predicted mask could not be saved for {os.path.basename(target_image_path)}.")

    except FileNotFoundError:
        print(f"Error: Target image file not found: {target_image_path}")
    except Exception as e:
        print(f"An unexpected error occurred while processing {os.path.basename(target_image_path)}: {e}")
        # Optionally close plot if it was created before the error
        try:
            plt.close(fig)
        except NameError: # If fig wasn't defined due to early error
            pass
        except Exception: # Catch any other potential errors during close
            pass


print("-" * 30)
print("Script finished processing all images.")

# %% [markdown]
# # Directory SegGPT implementation

# %%
import torch
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
import numpy as np
from transformers import SegGptImageProcessor, SegGptForImageSegmentation
import os
from matplotlib.colors import ListedColormap
import glob # To find image files
import random # To select reference images for plotting

# --- 1. Configuration ---
# Directories containing reference images and masks
reference_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/1_reference_image/images"
reference_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/2_reference_mask_from_OF/masks"

# Directory containing target images
target_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/3_target_image_s/images"

# --- OUTPUT Directories ---
# Directory to save ONLY the PREDICTED BINARY MASKS (target_name.png)
output_pred_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks_only" # <<< NEW: For binary masks
# Directory to save output PLOTS (2x3 layout)
output_plot_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/6_output_plots_2x3" # <<< NEW: For the 2x3 plots

# Assumed mask file extension
MASK_EXTENSION = ".png"
# Assumed image file extensions
IMAGE_EXTENSIONS = ["*.png", "*.jpg", "*.jpeg"]

# Ensure output directories exist
os.makedirs(output_pred_mask_dir, exist_ok=True) # <<< Create predicted mask directory
os.makedirs(output_plot_dir, exist_ok=True)
print(f"Output predicted binary masks will be saved to: {output_pred_mask_dir}") # <<< Updated
print(f"Output plots (2x3) will be saved to: {output_plot_dir}")

# --- 2. Setup Model and Device ---
print("Loading model, processor, and setting up device...")
try:
    model_name = "BAAI/seggpt-vit-large"
    processor = SegGptImageProcessor.from_pretrained(model_name)
    model = SegGptForImageSegmentation.from_pretrained(model_name)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    print(f"Using device: {device}")
except Exception as e:
    print(f"Error during model setup: {e}")
    exit()

# --- 3. Find Reference and Target Files ---
print(f"Looking for reference images in: {reference_image_dir}")
print(f"Looking for reference masks in: {reference_mask_dir}")
print(f"Looking for target images in: {target_image_dir}")

# Find all reference image files
all_ref_image_files = []
for ext in IMAGE_EXTENSIONS:
    all_ref_image_files.extend(glob.glob(os.path.join(reference_image_dir, ext)))

# Create a list of valid reference pairs (image + mask)
valid_ref_pairs = []
for ref_img_path in all_ref_image_files:
    ref_base = os.path.splitext(os.path.basename(ref_img_path))[1]
    # ref_base = os.path.splitext(os.path.basename(ref_img_path))[0]
    ref_mask_path = os.path.join(reference_mask_dir, ref_base + MASK_EXTENSION)
    if os.path.exists(ref_mask_path):
        valid_ref_pairs.append({"image": ref_img_path, "mask": ref_mask_path})
    else:
        print(f"  Warning: Mask not found for reference image: {ref_img_path}. Skipping this ref.")


if not valid_ref_pairs:
    print(f"Error: No valid reference image/mask pairs found.")
    exit()
print(f"Found {len(valid_ref_pairs)} valid reference pairs.")

# Find all target image files
target_image_files = []
for ext in IMAGE_EXTENSIONS:
    target_image_files.extend(glob.glob(os.path.join(target_image_dir, ext)))

if not target_image_files:
    print(f"Error: No target image files found in {target_image_dir}")
    exit()
print(f"Found {len(target_image_files)} target images.")


# Prepare Colormaps (once)
cmap_pred_overlay = plt.get_cmap('jet') # Colormap for prediction overlay
ref_overlay_color = np.array([1.0, 1.0, 0.0]) # Yellow RGB (0-1 range) for reference overlay
ref_overlay_alpha = 0.6 # Alpha for reference overlay
pred_overlay_alpha = 0.5 # Alpha for prediction overlay

# Helper function to create overlays
def create_overlay(image_np_float, mask_np, color_rgb, alpha_val):
    """Creates an overlay image."""
    if image_np_float.shape[:2] != mask_np.shape:
         print(f"    Warning: Resizing mask ({mask_np.shape}) to match image ({image_np_float.shape[:2]}) for overlay.")
         mask_pil = Image.fromarray(mask_np)
         mask_pil_resized = mask_pil.resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         mask_np = np.array(mask_pil_resized)

    overlay = image_np_float.copy()
    mask_alpha = (mask_np > 0).astype(np.float32) * alpha_val # Alpha where mask is present
    mask_color_rgb = np.tile(color_rgb[None, None, :], mask_np.shape + (1,))
    alpha_mask = mask_alpha[:, :, None] # Add channel dim for broadcasting
    overlay = (1 - alpha_mask) * overlay + alpha_mask * mask_color_rgb
    return np.clip(overlay, 0, 1)

# Helper function to create prediction overlays (using colormap)
def create_prediction_overlay(image_np_float, pred_mask_np, cmap, alpha_val):
    """Creates an overlay image using a colormap for the mask."""
    if image_np_float.shape[:2] != pred_mask_np.shape:
         print(f"    Warning: Resizing prediction mask ({pred_mask_np.shape}) to match image ({image_np_float.shape[:2]}) for overlay.")
         mask_pil = Image.fromarray(pred_mask_np)
         mask_pil_resized = mask_pil.resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         pred_mask_np = np.array(mask_pil_resized)

    overlay = image_np_float.copy()
    pred_mask_np_norm = pred_mask_np / 255.0 # Normalize mask 0-1 for colormap
    pred_mask_colored_rgb = cmap(pred_mask_np_norm)[:, :, :3] # Apply colormap, take RGB
    pred_mask_alpha = (pred_mask_np > 0).astype(np.float32) * alpha_val # Alpha where mask > 0
    alpha_predmask = pred_mask_alpha[:, :, None] # Add channel dim
    overlay = (1 - alpha_predmask) * overlay + alpha_predmask * pred_mask_colored_rgb
    return np.clip(overlay, 0, 1)


# --- 4. Process Each Target Image ---
# We will use the *first* valid reference pair for prediction for simplicity,
# but plot 3 potentially different reference pairs for visualization.
prediction_ref_pair = valid_ref_pairs[0] # Use the first valid pair for all predictions
print(f"Using reference pair for prediction: Image='{os.path.basename(prediction_ref_pair['image'])}', Mask='{os.path.basename(prediction_ref_pair['mask'])}'")

# Load the reference data for prediction ONCE
try:
    pred_ref_image = Image.open(prediction_ref_pair['image']).convert("RGB")
    pred_ref_mask = Image.open(prediction_ref_pair['mask']).convert("L") # Ensure mask is grayscale
    # Resize mask to match image if necessary (model input expects matching size)
    if pred_ref_mask.size != pred_ref_image.size:
        print(f"  Resizing prediction reference mask {os.path.basename(prediction_ref_pair['mask'])} to match image {os.path.basename(prediction_ref_pair['image'])} size.")
        pred_ref_mask = pred_ref_mask.resize(pred_ref_image.size, Image.NEAREST)
except Exception as e:
    print(f"Error loading the primary reference pair for prediction: {e}")
    exit()


# Select up to 3 reference pairs for plotting
num_refs_to_plot = min(len(valid_ref_pairs), 3)
plot_ref_pairs = random.sample(valid_ref_pairs, num_refs_to_plot)
print(f"Selected {num_refs_to_plot} reference pairs for plotting examples.")

# Load reference data for plotting ONCE
plot_ref_data = []
print("Loading reference data for plotting...")
for i, pair in enumerate(plot_ref_pairs):
    try:
        ref_img = Image.open(pair['image']).convert("RGB")
        ref_mask = Image.open(pair['mask']).convert("L")

        ref_img_np = np.array(ref_img).astype(np.float32) / 255.0
        ref_mask_np = np.array(ref_mask) # Grayscale numpy array 0-255

        # Create reference overlay (Yellow)
        ref_overlay = create_overlay(ref_img_np, ref_mask_np, ref_overlay_color, ref_overlay_alpha)
        plot_ref_data.append({
            'image': ref_img, # Keep PIL image if needed later
            'mask': ref_mask,   # Keep PIL image if needed later
            'overlay_np': ref_overlay,
            'name': os.path.basename(pair['image'])
        })
        print(f"  Loaded plot reference {i+1}: {os.path.basename(pair['image'])}")
    except Exception as e:
        print(f"  Error loading reference pair for plotting ('{os.path.basename(pair['image'])}'): {e}. Skipping this one for plot.")
# Ensure we have enough placeholders if loading failed for some plot refs
while len(plot_ref_data) < 3:
     plot_ref_data.append(None) # Add None placeholders if fewer than 3 loaded


total_processed = 0
for target_image_path in target_image_files:
    target_base_filename = os.path.splitext(os.path.basename(target_image_path))[0]
    print("-" * 40)
    print(f"Processing TARGET: {os.path.basename(target_image_path)}")

    # Define output filenames for this target
    output_pred_mask_filename = os.path.join(output_pred_mask_dir, f"{target_base_filename}.png") # <<< Simple name for mask
    output_plot_filename = os.path.join(output_plot_dir, f"plot_{target_base_filename}.png") # <<< Simple name for plot

    fig = None # Initialize fig to None for error handling
    try:
        # --- 4a. Load Target Image ---
        target_image = Image.open(target_image_path).convert("RGB")
        target_image_np_float = np.array(target_image).astype(np.float32) / 255.0

        # --- 4b. Prepare Inputs for the Model (using the chosen prediction reference) ---
        inputs = processor(
            images=[target_image],             # Target image
            prompt_images=[pred_ref_image],    # Reference image for prediction
            prompt_masks=[pred_ref_mask],      # Reference mask for prediction
            return_tensors="pt"
        )
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # --- 4c. Run Inference and Post-process ---
        pred_mask = None # Reset prediction mask
        pred_mask_np = None # Reset numpy version
        try:
            with torch.no_grad():
                outputs = model(**inputs)
            target_sizes = [target_image.size[::-1]] # Get target size (H, W)
            processed_output = processor.post_process_semantic_segmentation(outputs, target_sizes=target_sizes)

            # Extract predicted mask (expecting a list containing one tensor or PIL image)
            if isinstance(processed_output, list) and len(processed_output) > 0:
                 if isinstance(processed_output[0], torch.Tensor):
                     # Assuming output tensor needs thresholding/conversion
                     pred_mask_tensor = processed_output[0].cpu().squeeze()
                     # Threshold: Assume model output is logits or probabilities > 0 is foreground
                     # Or if it's class indices, non-zero index is foreground
                     # Let's assume simple thresholding for binary case
                     pred_mask_np_interim = (pred_mask_tensor.numpy() > 0.5).astype(np.uint8) * 255 # Threshold and scale to 0/255
                     pred_mask = Image.fromarray(pred_mask_np_interim, mode='L')
                     pred_mask_np = pred_mask_np_interim # Keep numpy version
                 elif isinstance(processed_output[0], Image.Image):
                     pred_mask = processed_output[0].convert('L') # Ensure grayscale
                     pred_mask_np = np.array(pred_mask) # Convert to numpy
                 else:
                    print("    Warning: Unexpected output type from processor.post_process_semantic_segmentation.")

            if pred_mask is None:
                print("    Inference or post-processing failed to produce a valid mask.")
                continue # Skip to next target image if prediction fails

        except Exception as e:
            print(f"    Error during inference or post-processing: {e}")
            continue # Skip to next target image

        # --- 4d. Save the Predicted Binary Mask ---
        try:
            # Ensure the mask is purely binary 0 or 255 if needed, although pred_mask_np should be already
            # binary_mask_np = ((pred_mask_np > 128).astype(np.uint8) * 255) # Optional re-binarization
            # binary_mask_pil = Image.fromarray(binary_mask_np, mode='L')
            # save the already processed pred_mask
            pred_mask.save(output_pred_mask_filename)
            print(f"    Saved predicted binary mask: {output_pred_mask_filename}")
        except Exception as e:
            print(f"    Error saving predicted binary mask: {e}")
            # Continue to plotting even if saving fails, but maybe log it

        # --- 4e. Create Prediction Overlay ---
        try:
            prediction_overlay = create_prediction_overlay(
                target_image_np_float,
                pred_mask_np,
                cmap_pred_overlay,
                pred_overlay_alpha
            )
        except Exception as e:
            print(f"    Error creating prediction overlay: {e}")
            prediction_overlay = target_image_np_float # Fallback to show target image if overlay fails


        # --- 4f. Create and Save the 2x3 Plot ---
        try:
            fig, axes = plt.subplots(2, 3, figsize=(18, 10)) # Adjusted figsize slightly
            fig.suptitle(f"Segmentation Result for: {os.path.basename(target_image_path)}\n(Using Ref: {os.path.basename(prediction_ref_pair['image'])})", fontsize=14)

            # Row 1: Reference Examples
            for i in range(3):
                ax = axes[0, i]
                if i < len(plot_ref_data) and plot_ref_data[i] is not None:
                    ax.imshow(plot_ref_data[i]['overlay_np'])
                    ax.set_title(f"Ref Example {i+1}: {plot_ref_data[i]['name']}")
                else:
                    ax.set_title(f"Ref Example {i+1}: N/A")
                    ax.set_xticks([])
                    ax.set_yticks([])
                    ax.set_facecolor('lightgray') # Indicate empty slot
                ax.axis('off')

            # Row 2: Target and Prediction Results
            axes[1, 0].imshow(target_image)
            axes[1, 0].set_title("Target Image")
            axes[1, 0].axis('off')

            axes[1, 1].imshow(pred_mask_np, cmap='gray', vmin=0, vmax=255) # Show predicted mask (binary)
            axes[1, 1].set_title("Predicted Mask")
            axes[1, 1].axis('off')

            axes[1, 2].imshow(prediction_overlay) # Show prediction overlay
            axes[1, 2].set_title("Prediction Overlay")
            axes[1, 2].axis('off')

            plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout rect for suptitle
            plt.savefig(output_plot_filename)
            print(f"    Saved plot: {output_plot_filename}")
            plt.close(fig) # Close the figure to free memory
            total_processed += 1

        except Exception as plot_save_e:
            print(f"    Error during plotting or saving plot: {plot_save_e}")
            if fig is not None:
               try: plt.close(fig)
               except Exception: pass # Ignore errors during closing if already failed

    except FileNotFoundError as e:
        print(f"  Error: Target File not found: {e}. Skipping.")
    except Exception as e:
        print(f"  An unexpected error occurred processing target {os.path.basename(target_image_path)}: {e}")
        if fig is not None:
            try: plt.close(fig)
            except Exception: pass

# --- End of Loop ---
print("-" * 40)
print(f"Script finished. Successfully processed and saved results for {total_processed} target images.")

# %% [markdown]
# # Output with GT

# %%
import torch
from PIL import Image, ImageOps, ImageDraw # Added ImageDraw for drawing boxes
import matplotlib.pyplot as plt
import numpy as np
from transformers import SegGptImageProcessor, SegGptForImageSegmentation
import os
# from matplotlib.colors import ListedColormap # Not strictly needed if using standard cmap
import glob # To find image files
import random # To select reference images for plotting
# import matplotlib.patches as patches # Alternative way to draw boxes, ImageDraw is often simpler here

# --- 1. Configuration ---
# Directories containing reference images and masks
reference_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/1_reference_image/images"
reference_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/2_reference_mask_from_OF/masks"

# Directory containing target images
target_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/3_target_image_s/images"

# <<<--- NEW: COCO Ground Truth Mask Directory --->>>
# Set to None or "" to disable loading/plotting COCO GT masks
coco_gt_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/COCO GT/masks"
# coco_gt_mask_dir = None # Example: Set to None to turn off GT mask usage

# --- OUTPUT Directories ---
# Directory to save ONLY the PREDICTED BINARY MASKS (target_name.png)
output_pred_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks_only"
# Directory to save output PLOTS (2x3 layout)
output_plot_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/6_output_plots_2x3_with_GT" # Renamed for clarity

# Assumed mask file extension
MASK_EXTENSION = ".png"
# Assumed image file extensions
IMAGE_EXTENSIONS = ["*.png", "*.jpg", "*.jpeg"]

# --- Setup COCO GT Usage ---
use_coco_gt = False
if coco_gt_mask_dir and os.path.isdir(coco_gt_mask_dir):
    use_coco_gt = True
    print(f"COCO Ground Truth masks will be loaded from: {coco_gt_mask_dir}")
else:
    print("COCO Ground Truth mask directory not provided or invalid. GT masks will not be used.")

# Ensure output directories exist
os.makedirs(output_pred_mask_dir, exist_ok=True)
os.makedirs(output_plot_dir, exist_ok=True)
print(f"Output predicted binary masks will be saved to: {output_pred_mask_dir}")
print(f"Output plots (2x3) will be saved to: {output_plot_dir}")

# --- 2. Setup Model and Device ---
# (Keep this section as is)
print("Loading model, processor, and setting up device...")
try:
    model_name = "BAAI/seggpt-vit-large"
    processor = SegGptImageProcessor.from_pretrained(model_name)
    model = SegGptForImageSegmentation.from_pretrained(model_name)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    print(f"Using device: {device}")
except Exception as e:
    print(f"Error during model setup: {e}")
    exit()

# --- 3. Find Reference and Target Files ---
# (Keep this section as is, including valid_ref_pairs logic)
print(f"Looking for reference images in: {reference_image_dir}")
print(f"Looking for reference masks in: {reference_mask_dir}")
print(f"Looking for target images in: {target_image_dir}")

# Find all reference image files
all_ref_image_files = []
for ext in IMAGE_EXTENSIONS:
    all_ref_image_files.extend(glob.glob(os.path.join(reference_image_dir, ext)))

# Create a list of valid reference pairs (image + mask)
valid_ref_pairs = []
for ref_img_path in all_ref_image_files:
    ref_base = os.path.splitext(os.path.basename(ref_img_path))[0]
    ref_mask_path = os.path.join(reference_mask_dir, ref_base + MASK_EXTENSION)
    if os.path.exists(ref_mask_path):
        valid_ref_pairs.append({"image": ref_img_path, "mask": ref_mask_path})
    else:
        print(f"  Warning: Mask not found for reference image: {ref_img_path}. Skipping this ref.")

if not valid_ref_pairs:
    print(f"Error: No valid reference image/mask pairs found.")
    exit()
print(f"Found {len(valid_ref_pairs)} valid reference pairs.")

# Find all target image files
target_image_files = []
for ext in IMAGE_EXTENSIONS:
    target_image_files.extend(glob.glob(os.path.join(target_image_dir, ext)))

if not target_image_files:
    print(f"Error: No target image files found in {target_image_dir}")
    exit()
print(f"Found {len(target_image_files)} target images.")


# Prepare Colormaps (once)
cmap_pred_overlay = plt.get_cmap('jet') # Colormap for prediction overlay
ref_overlay_color = np.array([1.0, 1.0, 0.0]) # Yellow RGB (0-1 range) for reference overlay
ref_overlay_alpha = 0.6 # Alpha for reference overlay
pred_overlay_alpha = 0.5 # Alpha for prediction overlay
gt_bbox_color = (0, 255, 0) # LIME GREEN for GT bounding box (RGB tuple 0-255 for PIL)
gt_bbox_width = 2 # Width of the GT box outline

# Helper function to create overlays
def create_overlay(image_np_float, mask_np, color_rgb, alpha_val):
    """Creates an overlay image."""
    if image_np_float.shape[:2] != mask_np.shape:
         print(f"    Warning: Resizing mask ({mask_np.shape}) to match image ({image_np_float.shape[:2]}) for overlay.")
         mask_pil = Image.fromarray(mask_np)
         mask_pil_resized = mask_pil.resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         mask_np = np.array(mask_pil_resized)

    overlay = image_np_float.copy()
    mask_alpha = (mask_np > 0).astype(np.float32) * alpha_val # Alpha where mask is present
    mask_color_rgb = np.tile(color_rgb[None, None, :], mask_np.shape + (1,))
    alpha_mask = mask_alpha[:, :, None] # Add channel dim for broadcasting
    overlay = (1 - alpha_mask) * overlay + alpha_mask * mask_color_rgb
    return np.clip(overlay, 0, 1)

# Helper function to create prediction overlays (using colormap)
def create_prediction_overlay(image_np_float, pred_mask_np, cmap, alpha_val):
    """Creates an overlay image using a colormap for the mask."""
    if image_np_float.shape[:2] != pred_mask_np.shape:
         print(f"    Warning: Resizing prediction mask ({pred_mask_np.shape}) to match image ({image_np_float.shape[:2]}) for overlay.")
         mask_pil = Image.fromarray(pred_mask_np)
         mask_pil_resized = mask_pil.resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         pred_mask_np = np.array(mask_pil_resized)

    overlay = image_np_float.copy()
    # Normalize mask 0-1 for colormap, handle potential division by zero if max is 0
    max_val = pred_mask_np.max()
    if max_val > 0:
        pred_mask_np_norm = pred_mask_np / max_val
    else:
        pred_mask_np_norm = pred_mask_np.astype(float) # Keep as zeros if mask is empty

    pred_mask_colored_rgb = cmap(pred_mask_np_norm)[:, :, :3] # Apply colormap, take RGB
    pred_mask_alpha = (pred_mask_np > 0).astype(np.float32) * alpha_val # Alpha where mask > 0
    alpha_predmask = pred_mask_alpha[:, :, None] # Add channel dim
    overlay = (1 - alpha_predmask) * overlay + alpha_predmask * pred_mask_colored_rgb
    return np.clip(overlay, 0, 1)

# --- Function to get bounding box ---
def get_bounding_box(mask_np):
    """Calculates the bounding box of non-zero pixels in a mask."""
    rows = np.any(mask_np, axis=1)
    cols = np.any(mask_np, axis=0)
    if not np.any(rows) or not np.any(cols): # Check if mask is empty
        return None
    rmin, rmax = np.where(rows)[0][[0, -1]]
    cmin, cmax = np.where(cols)[0][[0, -1]]
    # Return as (xmin, ymin, xmax, ymax)
    return (cmin, rmin, cmax, rmax)


# --- 4. Process Each Target Image ---
# (Keep prediction reference selection and loading as is)
prediction_ref_pair = valid_ref_pairs[0]
print(f"Using reference pair for prediction: Image='{os.path.basename(prediction_ref_pair['image'])}', Mask='{os.path.basename(prediction_ref_pair['mask'])}'")
try:
    pred_ref_image = Image.open(prediction_ref_pair['image']).convert("RGB")
    pred_ref_mask = Image.open(prediction_ref_pair['mask']).convert("L")
    if pred_ref_mask.size != pred_ref_image.size:
        print(f"  Resizing prediction reference mask {os.path.basename(prediction_ref_pair['mask'])} to match image {os.path.basename(prediction_ref_pair['image'])} size.")
        pred_ref_mask = pred_ref_mask.resize(pred_ref_image.size, Image.NEAREST)
except Exception as e:
    print(f"Error loading the primary reference pair for prediction: {e}")
    exit()

# (Keep plot reference selection and loading as is)
num_refs_to_plot = min(len(valid_ref_pairs), 3)
plot_ref_pairs = random.sample(valid_ref_pairs, num_refs_to_plot)
print(f"Selected {num_refs_to_plot} reference pairs for plotting examples.")
plot_ref_data = []
print("Loading reference data for plotting...")
for i, pair in enumerate(plot_ref_pairs):
    try:
        ref_img = Image.open(pair['image']).convert("RGB")
        ref_mask = Image.open(pair['mask']).convert("L")
        ref_img_np = np.array(ref_img).astype(np.float32) / 255.0
        ref_mask_np = np.array(ref_mask)
        ref_overlay = create_overlay(ref_img_np, ref_mask_np, ref_overlay_color, ref_overlay_alpha)
        plot_ref_data.append({
            'image': ref_img,
            'mask': ref_mask,
            'overlay_np': ref_overlay,
            'name': os.path.basename(pair['image'])
        })
        print(f"  Loaded plot reference {i+1}: {os.path.basename(pair['image'])}")
    except Exception as e:
        print(f"  Error loading reference pair for plotting ('{os.path.basename(pair['image'])}'): {e}. Skipping this one for plot.")
while len(plot_ref_data) < 3:
     plot_ref_data.append(None)


total_processed = 0
for target_image_path in target_image_files:
    target_base_filename = os.path.splitext(os.path.basename(target_image_path))[0]
    print("-" * 40)
    print(f"Processing TARGET: {os.path.basename(target_image_path)}")

    # Define output filenames for this target
    output_pred_mask_filename = os.path.join(output_pred_mask_dir, f"{target_base_filename}.png")
    output_plot_filename = os.path.join(output_plot_dir, f"plot_{target_base_filename}.png")

    fig = None
    gt_mask_np = None # Initialize GT mask for this target
    gt_bbox = None # Initialize GT bbox for this target

    try:
        # --- 4a. Load Target Image ---
        target_image = Image.open(target_image_path).convert("RGB")
        target_image_np_float = np.array(target_image).astype(np.float32) / 255.0

        # --- 4a-bis. Load COCO Ground Truth Mask (if enabled and available) ---
        if use_coco_gt:
            gt_mask_filename = f"{target_base_filename}_mask.png" # Construct expected filename
            gt_mask_path = os.path.join(coco_gt_mask_dir, gt_mask_filename)
            if os.path.exists(gt_mask_path):
                try:
                    gt_mask_pil = Image.open(gt_mask_path).convert("L")
                    # Ensure GT mask has same dimensions as target image for bbox calculation
                    if gt_mask_pil.size != target_image.size:
                         print(f"    Warning: Resizing GT mask ({gt_mask_pil.size}) to match target image ({target_image.size}).")
                         gt_mask_pil = gt_mask_pil.resize(target_image.size, Image.NEAREST)

                    gt_mask_np = np.array(gt_mask_pil)
                    # Ensure mask is binary 0 or non-zero (e.g., 255)
                    gt_mask_np = ((gt_mask_np > 128).astype(np.uint8) * 255) # Force binary
                    gt_bbox = get_bounding_box(gt_mask_np) # Calculate bbox
                    if gt_bbox:
                        print(f"    Loaded COCO GT mask: {gt_mask_filename} and found BBox: {gt_bbox}")
                    else:
                        print(f"    Loaded COCO GT mask: {gt_mask_filename}, but it appears empty.")

                except Exception as e:
                    print(f"    Warning: Error loading or processing COCO GT mask {gt_mask_path}: {e}")
                    gt_mask_np = None # Reset on error
                    gt_bbox = None
            # else: # Optional: print if GT mask file is missing
            #     print(f"    Note: COCO GT mask not found: {gt_mask_path}")


        # --- 4b. Prepare Inputs for the Model ---
        # (Keep as is)
        inputs = processor(
            images=[target_image],
            prompt_images=[pred_ref_image],
            prompt_masks=[pred_ref_mask],
            return_tensors="pt"
        )
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # --- 4c. Run Inference and Post-process ---
        # (Keep as is, ensuring pred_mask and pred_mask_np are generated)
        pred_mask = None
        pred_mask_np = None
        try:
            with torch.no_grad():
                outputs = model(**inputs)
            target_sizes = [target_image.size[::-1]]
            processed_output = processor.post_process_semantic_segmentation(outputs, target_sizes=target_sizes)

            if isinstance(processed_output, list) and len(processed_output) > 0:
                 if isinstance(processed_output[0], torch.Tensor):
                     pred_mask_tensor = processed_output[0].cpu().squeeze()
                     # Using 0.5 threshold, adjust if model outputs logits differently
                     pred_mask_np_interim = (pred_mask_tensor.numpy() > 0.5).astype(np.uint8) * 255
                     pred_mask = Image.fromarray(pred_mask_np_interim, mode='L')
                     pred_mask_np = pred_mask_np_interim
                 elif isinstance(processed_output[0], Image.Image):
                     pred_mask = processed_output[0].convert('L')
                     pred_mask_np = np.array(pred_mask)
                 else:
                    print("    Warning: Unexpected output type from processor.post_process_semantic_segmentation.")

            if pred_mask is None or pred_mask_np is None: # Check both PIL and numpy versions
                print("    Inference or post-processing failed to produce a valid mask.")
                continue

        except Exception as e:
            print(f"    Error during inference or post-processing: {e}")
            continue

        # --- 4d. Save the Predicted Binary Mask ---
        # (Keep as is)
        try:
            pred_mask.save(output_pred_mask_filename)
            print(f"    Saved predicted binary mask: {output_pred_mask_filename}")
        except Exception as e:
            print(f"    Error saving predicted binary mask: {e}")


        # --- 4e. Create Prediction Overlay ---
        try:
            prediction_overlay_np = create_prediction_overlay(
                target_image_np_float,
                pred_mask_np,
                cmap_pred_overlay,
                pred_overlay_alpha
            )
        except Exception as e:
            print(f"    Error creating prediction overlay: {e}")
            prediction_overlay_np = target_image_np_float # Fallback


        # --- 4e-bis. Draw GT Bounding Box on Prediction Overlay (if available) ---
        final_overlay_for_plot = prediction_overlay_np.copy() # Start with prediction overlay
        plot_title_suffix = "" # To modify plot title if GT box is added

        if gt_bbox is not None:
            try:
                # Convert the numpy overlay (float 0-1) to PIL Image (uint8 0-255) to use ImageDraw
                overlay_pil = Image.fromarray((final_overlay_for_plot * 255).astype(np.uint8))
                draw = ImageDraw.Draw(overlay_pil)
                # Draw the rectangle: xy = [xmin, ymin, xmax, ymax]
                draw.rectangle(gt_bbox, outline=gt_bbox_color, width=gt_bbox_width)

                # Convert back to numpy float 0-1 for matplotlib display
                final_overlay_for_plot = np.array(overlay_pil).astype(np.float32) / 255.0
                plot_title_suffix = " + GT BBox (Lime)"
                print(f"    Drew GT BBox onto final overlay.")

            except Exception as e:
                print(f"    Warning: Error drawing GT bounding box onto overlay: {e}")
                # Keep final_overlay_for_plot as the original prediction_overlay_np if drawing fails


        # --- 4f. Create and Save the 2x3 Plot ---
        try:
            fig, axes = plt.subplots(2, 3, figsize=(18, 10))
            fig.suptitle(f"Segmentation Result for: {os.path.basename(target_image_path)}\n(Using Ref: {os.path.basename(prediction_ref_pair['image'])})", fontsize=14)

            # Row 1: Reference Examples (Keep as is)
            for i in range(3):
                ax = axes[0, i]
                if i < len(plot_ref_data) and plot_ref_data[i] is not None:
                    ax.imshow(plot_ref_data[i]['overlay_np'])
                    ax.set_title(f"Ref Example {i+1}: {plot_ref_data[i]['name']}")
                else:
                    ax.set_title(f"Ref Example {i+1}: N/A")
                    ax.set_xticks([])
                    ax.set_yticks([])
                    ax.set_facecolor('lightgray')
                ax.axis('off')

            # Row 2: Target and Prediction Results
            axes[1, 0].imshow(target_image)
            axes[1, 0].set_title("Target Image")
            axes[1, 0].axis('off')

            axes[1, 1].imshow(pred_mask_np, cmap='gray', vmin=0, vmax=255)
            axes[1, 1].set_title("Predicted Mask")
            axes[1, 1].axis('off')

            # Show the final overlay (potentially with GT box drawn on it)
            axes[1, 2].imshow(final_overlay_for_plot)
            axes[1, 2].set_title(f"Prediction Overlay{plot_title_suffix}") # Use updated title
            axes[1, 2].axis('off')

            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            plt.savefig(output_plot_filename)
            print(f"    Saved plot: {output_plot_filename}")
            plt.close(fig)
            total_processed += 1

        except Exception as plot_save_e:
            print(f"    Error during plotting or saving plot: {plot_save_e}")
            if fig is not None:
               try: plt.close(fig)
               except Exception: pass

    except FileNotFoundError as e:
        print(f"  Error: Target File not found: {e}. Skipping.")
    except Exception as e:
        print(f"  An unexpected error occurred processing target {os.path.basename(target_image_path)}: {e}")
        if fig is not None:
            try: plt.close(fig)
            except Exception: pass

# --- End of Loop ---
print("-" * 40)
print(f"Script finished. Successfully processed and saved results for {total_processed} target images.")

# %%
import torch
from PIL import Image, ImageOps, ImageDraw # Keep ImageDraw just in case, though not used for bbox now
import matplotlib.pyplot as plt
import numpy as np
from transformers import SegGptImageProcessor, SegGptForImageSegmentation
import os
# from matplotlib.colors import ListedColormap
import glob # To find image files
import random # To select reference images for plotting

# --- 1. Configuration ---
# (Keep paths as they are)
reference_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/1_reference_image/images"
reference_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/2_reference_mask_from_OF/masks"
# target_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/3_target_image_s/images"
target_image_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/train/images"
coco_gt_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/COCO GT/masks"
# coco_gt_mask_dir = None # Set to None to disable

output_pred_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks_only"
output_plot_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/7_output_plots_2x3_with_GT_Overlay" # Renamed

MASK_EXTENSION = ".png"
IMAGE_EXTENSIONS = ["*.png", "*.jpg", "*.jpeg"]

# --- Setup COCO GT Usage ---
use_coco_gt = False
if coco_gt_mask_dir and os.path.isdir(coco_gt_mask_dir):
    use_coco_gt = True
    print(f"COCO Ground Truth masks will be loaded from: {coco_gt_mask_dir}")
else:
    print("COCO Ground Truth mask directory not provided or invalid. GT masks will not be used.")

os.makedirs(output_pred_mask_dir, exist_ok=True)
os.makedirs(output_plot_dir, exist_ok=True)
print(f"Output predicted binary masks will be saved to: {output_pred_mask_dir}")
print(f"Output plots (2x3) will be saved to: {output_plot_dir}")

# --- 2. Setup Model and Device ---
# (Keep as is)
print("Loading model, processor, and setting up device...")
try:
    model_name = "BAAI/seggpt-vit-large"
    processor = SegGptImageProcessor.from_pretrained(model_name)
    model = SegGptForImageSegmentation.from_pretrained(model_name)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    print(f"Using device: {device}")
except Exception as e:
    print(f"Error during model setup: {e}")
    exit()

# --- 3. Find Reference and Target Files ---
# (Keep as is)
print(f"Looking for reference images in: {reference_image_dir}")
print(f"Looking for reference masks in: {reference_mask_dir}")
print(f"Looking for target images in: {target_image_dir}")
all_ref_image_files = []
for ext in IMAGE_EXTENSIONS:
    all_ref_image_files.extend(glob.glob(os.path.join(reference_image_dir, ext)))
valid_ref_pairs = []
for ref_img_path in all_ref_image_files:
    ref_base = os.path.splitext(os.path.basename(ref_img_path))[0]
    ref_mask_path = os.path.join(reference_mask_dir, ref_base + MASK_EXTENSION)
    if os.path.exists(ref_mask_path):
        valid_ref_pairs.append({"image": ref_img_path, "mask": ref_mask_path})
    else:
        print(f"  Warning: Mask not found for reference image: {ref_img_path}. Skipping this ref.")
if not valid_ref_pairs:
    print(f"Error: No valid reference image/mask pairs found.")
    exit()
print(f"Found {len(valid_ref_pairs)} valid reference pairs.")
target_image_files = []
for ext in IMAGE_EXTENSIONS:
    target_image_files.extend(glob.glob(os.path.join(target_image_dir, ext)))
if not target_image_files:
    print(f"Error: No target image files found in {target_image_dir}")
    exit()
print(f"Found {len(target_image_files)} target images.")


# Prepare Colormaps and Colors (once)
cmap_pred_overlay = plt.get_cmap('jet') # Colormap for prediction overlay
ref_overlay_color = np.array([1.0, 1.0, 0.0]) # Yellow RGB (0-1 range) for reference overlay
ref_overlay_alpha = 0.6
pred_overlay_alpha = 0.5
# <<<--- NEW: Color and Alpha for COCO GT Mask Overlay --->>>
gt_overlay_color = np.array([0.0, 1.0, 0.0]) # LIME GREEN (float 0-1)
gt_overlay_alpha = 0.7 # Adjust transparency as needed


# (Keep Helper functions: create_overlay, create_prediction_overlay as is)
def create_overlay(image_np_float, mask_np, color_rgb, alpha_val):
    """Creates an overlay image."""
    if image_np_float.shape[:2] != mask_np.shape:
         # print(f"    Warning: Resizing mask ({mask_np.shape}) to match image ({image_np_float.shape[:2]}) for overlay.")
         mask_pil = Image.fromarray(mask_np)
         mask_pil_resized = mask_pil.resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         mask_np = np.array(mask_pil_resized)

    overlay = image_np_float.copy()
    mask_alpha = (mask_np > 0).astype(np.float32) * alpha_val # Alpha where mask is present
    mask_color_rgb = np.tile(color_rgb[None, None, :], mask_np.shape + (1,))
    alpha_mask = mask_alpha[:, :, None] # Add channel dim for broadcasting
    overlay = (1 - alpha_mask) * overlay + alpha_mask * mask_color_rgb
    return np.clip(overlay, 0, 1)

def create_prediction_overlay(image_np_float, pred_mask_np, cmap, alpha_val):
    """Creates an overlay image using a colormap for the mask."""
    if image_np_float.shape[:2] != pred_mask_np.shape:
         # print(f"    Warning: Resizing prediction mask ({pred_mask_np.shape}) to match image ({image_np_float.shape[:2]}) for overlay.")
         mask_pil = Image.fromarray(pred_mask_np)
         mask_pil_resized = mask_pil.resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         pred_mask_np = np.array(mask_pil_resized)

    overlay = image_np_float.copy()
    max_val = pred_mask_np.max()
    if max_val > 0:
        pred_mask_np_norm = pred_mask_np / max_val
    else:
        pred_mask_np_norm = pred_mask_np.astype(float)

    pred_mask_colored_rgb = cmap(pred_mask_np_norm)[:, :, :3]
    pred_mask_alpha = (pred_mask_np > 0).astype(np.float32) * alpha_val
    alpha_predmask = pred_mask_alpha[:, :, None]
    overlay = (1 - alpha_predmask) * overlay + alpha_predmask * pred_mask_colored_rgb
    return np.clip(overlay, 0, 1)

# --- Remove get_bounding_box function (not needed) ---

# --- 4. Process Each Target Image ---
# (Keep prediction reference selection and loading as is)
prediction_ref_pair = valid_ref_pairs[0] # Still uses only the FIRST reference for actual prediction
print(f"Using reference pair for prediction: Image='{os.path.basename(prediction_ref_pair['image'])}', Mask='{os.path.basename(prediction_ref_pair['mask'])}'")
try:
    pred_ref_image = Image.open(prediction_ref_pair['image']).convert("RGB")
    pred_ref_mask = Image.open(prediction_ref_pair['mask']).convert("L")
    if pred_ref_mask.size != pred_ref_image.size:
        # print(f"  Resizing prediction reference mask {os.path.basename(prediction_ref_pair['mask'])} to match image {os.path.basename(prediction_ref_pair['image'])} size.")
        pred_ref_mask = pred_ref_mask.resize(pred_ref_image.size, Image.NEAREST)
except Exception as e:
    print(f"Error loading the primary reference pair for prediction: {e}")
    exit()

# (Keep plot reference selection and loading as is - these are just for display)
num_refs_to_plot = min(len(valid_ref_pairs), 3)
plot_ref_pairs = random.sample(valid_ref_pairs, num_refs_to_plot)
print(f"Selected {num_refs_to_plot} reference pairs for plotting examples.")
plot_ref_data = []
print("Loading reference data for plotting...")
for i, pair in enumerate(plot_ref_pairs):
    try:
        ref_img = Image.open(pair['image']).convert("RGB")
        ref_mask = Image.open(pair['mask']).convert("L")
        ref_img_np = np.array(ref_img).astype(np.float32) / 255.0
        ref_mask_np = np.array(ref_mask)
        ref_overlay = create_overlay(ref_img_np, ref_mask_np, ref_overlay_color, ref_overlay_alpha)
        plot_ref_data.append({
            'image': ref_img, 'mask': ref_mask,
            'overlay_np': ref_overlay, 'name': os.path.basename(pair['image'])
        })
        print(f"  Loaded plot reference {i+1}: {os.path.basename(pair['image'])}")
    except Exception as e:
        print(f"  Error loading reference pair for plotting ('{os.path.basename(pair['image'])}'): {e}. Skipping this one for plot.")
while len(plot_ref_data) < 3:
     plot_ref_data.append(None)


total_processed = 0
for target_image_path in target_image_files:
    target_base_filename = os.path.splitext(os.path.basename(target_image_path))[0]
    print("-" * 40)
    print(f"Processing TARGET: {os.path.basename(target_image_path)}")

    output_pred_mask_filename = os.path.join(output_pred_mask_dir, f"{target_base_filename}.png")
    output_plot_filename = os.path.join(output_plot_dir, f"plot_{target_base_filename}.png")

    fig = None
    gt_mask_np = None # Initialize GT mask for this target

    try:
        # --- 4a. Load Target Image ---
        target_image = Image.open(target_image_path).convert("RGB")
        target_image_np_float = np.array(target_image).astype(np.float32) / 255.0

        # --- 4a-bis. Load COCO Ground Truth Mask (if enabled and available) ---
        if use_coco_gt:
            gt_mask_filename = f"{target_base_filename}_mask.png"
            gt_mask_path = os.path.join(coco_gt_mask_dir, gt_mask_filename)
            if os.path.exists(gt_mask_path):
                try:
                    gt_mask_pil = Image.open(gt_mask_path).convert("L")
                    # Ensure GT mask has same dimensions as target image for overlay
                    if gt_mask_pil.size != target_image.size:
                         print(f"    Warning: Resizing GT mask ({gt_mask_pil.size}) to match target image ({target_image.size}).")
                         gt_mask_pil = gt_mask_pil.resize(target_image.size, Image.NEAREST)

                    gt_mask_np = np.array(gt_mask_pil)
                    # Ensure mask is binary 0 or non-zero (e.g., 255)
                    gt_mask_np = ((gt_mask_np > 128).astype(np.uint8) * 255) # Force binary
                    if np.any(gt_mask_np): # Check if mask is not empty
                        print(f"    Loaded COCO GT mask: {gt_mask_filename}")
                    else:
                        print(f"    Loaded COCO GT mask: {gt_mask_filename}, but it appears empty.")
                        gt_mask_np = None # Treat empty mask as if not loaded for overlay step
                except Exception as e:
                    print(f"    Warning: Error loading or processing COCO GT mask {gt_mask_path}: {e}")
                    gt_mask_np = None # Reset on error
            # else:
            #     print(f"    Note: COCO GT mask not found: {gt_mask_path}")

        # --- 4b. Prepare Inputs for the Model ---
        # Uses ONLY pred_ref_image and pred_ref_mask loaded earlier
        inputs = processor(
            images=[target_image],
            prompt_images=[pred_ref_image],
            prompt_masks=[pred_ref_mask],
            return_tensors="pt"
        )
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # --- 4c. Run Inference and Post-process ---
        # (Keep as is)
        pred_mask = None
        pred_mask_np = None
        try:
            with torch.no_grad():
                outputs = model(**inputs)
            target_sizes = [target_image.size[::-1]]
            processed_output = processor.post_process_semantic_segmentation(outputs, target_sizes=target_sizes)
            # (Mask extraction logic remains the same)
            if isinstance(processed_output, list) and len(processed_output) > 0:
                 if isinstance(processed_output[0], torch.Tensor):
                     pred_mask_tensor = processed_output[0].cpu().squeeze()
                     pred_mask_np_interim = (pred_mask_tensor.numpy() > 0.5).astype(np.uint8) * 255
                     pred_mask = Image.fromarray(pred_mask_np_interim, mode='L')
                     pred_mask_np = pred_mask_np_interim
                 elif isinstance(processed_output[0], Image.Image):
                     pred_mask = processed_output[0].convert('L')
                     pred_mask_np = np.array(pred_mask)
                 else:
                    print("    Warning: Unexpected output type from processor.")
            if pred_mask is None or pred_mask_np is None:
                print("    Inference or post-processing failed to produce a valid mask.")
                continue
        except Exception as e:
            print(f"    Error during inference or post-processing: {e}")
            continue

        # --- 4d. Save the Predicted Binary Mask ---
        # (Keep as is)
        try:
            pred_mask.save(output_pred_mask_filename)
            print(f"    Saved predicted binary mask: {output_pred_mask_filename}")
        except Exception as e:
            print(f"    Error saving predicted binary mask: {e}")

        # --- 4e. Create Prediction Overlay ---
        try:
            prediction_overlay_np = create_prediction_overlay(
                target_image_np_float,
                pred_mask_np,
                cmap_pred_overlay,
                pred_overlay_alpha
            )
        except Exception as e:
            print(f"    Error creating prediction overlay: {e}")
            prediction_overlay_np = target_image_np_float

        # --- 4e-bis. Overlay GT Mask onto the Prediction Overlay (if available) ---
        # Start with the prediction overlay (target + predicted mask)
        final_overlay_for_plot = prediction_overlay_np.copy()
        plot_title_suffix = "" # To modify plot title if GT mask is added

        if gt_mask_np is not None: # Check if GT mask was successfully loaded and is not empty
            try:
                # Create alpha mask for GT overlay (1 where GT mask is > 0, 0 otherwise)
                gt_alpha_mask = (gt_mask_np > 0).astype(np.float32) * gt_overlay_alpha
                # Add channel dimension for broadcasting
                gt_alpha_mask = gt_alpha_mask[:, :, None]

                # Create a solid color layer for the GT mask regions
                gt_color_layer = np.tile(gt_overlay_color[None, None, :], final_overlay_for_plot.shape[:2] + (1,))

                # Blend: (1 - alpha) * background + alpha * foreground
                final_overlay_for_plot = (1 - gt_alpha_mask) * final_overlay_for_plot + gt_alpha_mask * gt_color_layer
                final_overlay_for_plot = np.clip(final_overlay_for_plot, 0, 1) # Ensure values are valid

                plot_title_suffix = " + GT Mask (Lime)"
                print(f"    Overlayed GT mask onto final plot image.")

            except Exception as e:
                print(f"    Warning: Error overlaying GT mask: {e}")
                # If overlay fails, final_overlay_for_plot remains the prediction_overlay_np


        # --- 4f. Create and Save the 2x3 Plot ---
        try:
            fig, axes = plt.subplots(2, 3, figsize=(18, 10))
            fig.suptitle(f"Segmentation Result for: {os.path.basename(target_image_path)}\n(Using Single Ref: {os.path.basename(prediction_ref_pair['image'])})", fontsize=14) # Updated title

            # Row 1: Reference Examples (Keep as is)
            for i in range(3):
                ax = axes[0, i]
                if i < len(plot_ref_data) and plot_ref_data[i] is not None:
                    ax.imshow(plot_ref_data[i]['overlay_np'])
                    ax.set_title(f"Ref Example {i+1}: {plot_ref_data[i]['name']}")
                else:
                    ax.set_title(f"Ref Example {i+1}: N/A")
                    ax.set_xticks([]); ax.set_yticks([])
                    ax.set_facecolor('lightgray')
                ax.axis('off')

            # Row 2: Target and Prediction Results
            axes[1, 0].imshow(target_image)
            axes[1, 0].set_title("Target Image")
            axes[1, 0].axis('off')

            axes[1, 1].imshow(pred_mask_np, cmap='gray', vmin=0, vmax=255)
            axes[1, 1].set_title("Predicted Mask")
            axes[1, 1].axis('off')

            # Show the final combined overlay (prediction overlay + GT mask overlay)
            axes[1, 2].imshow(final_overlay_for_plot)
            axes[1, 2].set_title(f"Prediction Overlay{plot_title_suffix}") # Use updated title
            axes[1, 2].axis('off')

            plt.tight_layout(rect=[0, 0.03, 1, 0.95])
            plt.savefig(output_plot_filename)
            print(f"    Saved plot: {output_plot_filename}")
            plt.close(fig)
            total_processed += 1

        except Exception as plot_save_e:
            print(f"    Error during plotting or saving plot: {plot_save_e}")
            if fig is not None:
               try: plt.close(fig)
               except Exception: pass

    except FileNotFoundError as e:
        print(f"  Error: Target File not found: {e}. Skipping.")
    except Exception as e:
        print(f"  An unexpected error occurred processing target {os.path.basename(target_image_path)}: {e}")
        if fig is not None:
            try: plt.close(fig)
            except Exception: pass

# --- End of Loop ---
print("-" * 40)
print(f"Script finished. Successfully processed and saved results for {total_processed} target images.")

# %% [markdown]
# # Scores

# %%
import os
import glob
from PIL import Image
import numpy as np
from sklearn.metrics import (
    jaccard_score,  # IoU
    f1_score,       # Dice
    accuracy_score, # Pixel Accuracy
    precision_score,
    recall_score,
    confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # For easier handling of metrics

# --- Configuration ---
pred_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks"
gt_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/COCO GT/masks"
# Optional: Original image dir if needed later, but not required for metrics
# target_image_dir = "/home/druglord/Remote/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/3_target_image_s/images"

# Directory to save plots
output_plot_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/evaluation_plots_1112"
os.makedirs(output_plot_dir, exist_ok=True)

# Mask properties
GT_SUFFIX = "_mask.png"
PRED_EXTENSION = ".png" # Assuming prediction masks are png
POSITIVE_CLASS_LABEL = 1 # Assuming foreground is 1 after binarization

# --- Helper Function ---
def load_and_binarize_mask(mask_path, target_size=None):
    """Loads a mask, optionally resizes, and converts to binary 0/1 numpy array."""
    try:
        mask = Image.open(mask_path).convert('L') # Convert to grayscale
        if target_size and mask.size != target_size:
            print(f"    Warning: Resizing mask {os.path.basename(mask_path)} from {mask.size} to {target_size}")
            mask = mask.resize(target_size, Image.NEAREST)

        mask_np = np.array(mask)
        # Binarize: Assume non-zero pixels are foreground (adjust threshold if needed)
        binary_mask = (mask_np > 128).astype(np.uint8) # Use 128 as common threshold
        return binary_mask
    except FileNotFoundError:
        print(f"    Error: Mask file not found: {mask_path}")
        return None
    except Exception as e:
        print(f"    Error loading/processing mask {mask_path}: {e}")
        return None

# --- Find prediction files and match with GT ---
print(f"Searching for predicted masks in: {pred_mask_dir}")
pred_mask_files = glob.glob(os.path.join(pred_mask_dir, f"*{PRED_EXTENSION}"))
print(f"Found {len(pred_mask_files)} predicted mask files.")

if not pred_mask_files:
    print("Error: No prediction files found. Exiting.")
    exit()

results = [] # Store results for each image pair

print("\nProcessing image pairs and calculating metrics...")
processed_count = 0
skipped_count = 0

for pred_path in pred_mask_files:
    pred_basename = os.path.basename(pred_path)
    base_name_no_ext = os.path.splitext(pred_basename)[0]

    gt_filename = f"{base_name_no_ext}{GT_SUFFIX}"
    gt_path = os.path.join(gt_mask_dir, gt_filename)

    print(f"  Processing: Pred='{pred_basename}', Expecting GT='{gt_filename}'")

    if not os.path.exists(gt_path):
        print(f"    Warning: Corresponding GT mask not found. Skipping.")
        skipped_count += 1
        continue

    # Load prediction mask first to get target size (optional, safer)
    pred_mask_np = load_and_binarize_mask(pred_path)
    if pred_mask_np is None:
        skipped_count += 1
        continue

    # Load GT mask, resizing to match prediction if necessary
    # Note: It's generally better if they are already the same size.
    # Resizing GT can slightly affect metrics.
    gt_mask_np = load_and_binarize_mask(gt_path, target_size=(pred_mask_np.shape[1], pred_mask_np.shape[0])) # W, H for PIL size
    if gt_mask_np is None:
        skipped_count += 1
        continue

    # Ensure masks have the same shape after loading and potential resize
    if pred_mask_np.shape != gt_mask_np.shape:
        print(f"    Error: Mask shapes mismatch after loading/resizing ({pred_mask_np.shape} vs {gt_mask_np.shape}). Skipping.")
        skipped_count += 1
        continue

    # Flatten arrays for sklearn metrics
    pred_flat = pred_mask_np.flatten()
    gt_flat = gt_mask_np.flatten()

    # Handle case where GT mask is all background (avoid division by zero in some metrics)
    if np.sum(gt_flat) == 0:
        print("    Note: GT mask is empty (all background).")
        # If prediction is also empty, IoU/Dice are often defined as 1.
        # If prediction is not empty, IoU/Dice are 0.
        iou_score = 1.0 if np.sum(pred_flat) == 0 else 0.0
        dice_score = 1.0 if np.sum(pred_flat) == 0 else 0.0
        # Precision is undefined (0/0) if pred is empty, 0 if pred has FPs.
        precision = 1.0 if np.sum(pred_flat) == 0 else 0.0 # Convention: Perfect precision if nothing predicted for empty GT
        recall = 1.0 # Convention: Found all "zero" positive pixels
        accuracy = accuracy_score(gt_flat, pred_flat) # Still calculable
        tn, fp, fn, tp = confusion_matrix(gt_flat, pred_flat, labels=[0, POSITIVE_CLASS_LABEL]).ravel()

    # Handle case where prediction mask is all background
    elif np.sum(pred_flat) == 0:
        print("    Note: Predicted mask is empty (all background).")
        iou_score = 0.0 # FN > 0 (unless GT also empty)
        dice_score = 0.0
        precision = 1.0 # Convention: Perfect precision if nothing predicted
        # Recall is 0 because TP = 0 and FN > 0
        recall = 0.0
        accuracy = accuracy_score(gt_flat, pred_flat)
        tn, fp, fn, tp = confusion_matrix(gt_flat, pred_flat, labels=[0, POSITIVE_CLASS_LABEL]).ravel()

    # Normal case: Both masks potentially have foreground pixels
    else:
        try:
            # Calculate standard metrics
            # Use pos_label=POSITIVE_CLASS_LABEL (usually 1)
            # zero_division=0 means metric is 0 if denominator is 0 (e.g., Precision=0 if TP+FP=0)
            iou_score = jaccard_score(gt_flat, pred_flat, pos_label=POSITIVE_CLASS_LABEL, average='binary', zero_division=0)
            dice_score = f1_score(gt_flat, pred_flat, pos_label=POSITIVE_CLASS_LABEL, average='binary', zero_division=0)
            accuracy = accuracy_score(gt_flat, pred_flat)
            precision = precision_score(gt_flat, pred_flat, pos_label=POSITIVE_CLASS_LABEL, average='binary', zero_division=0)
            recall = recall_score(gt_flat, pred_flat, pos_label=POSITIVE_CLASS_LABEL, average='binary', zero_division=0)
            tn, fp, fn, tp = confusion_matrix(gt_flat, pred_flat, labels=[0, POSITIVE_CLASS_LABEL]).ravel()

        except Exception as e:
            print(f"    Error calculating metrics for {pred_basename}: {e}. Skipping.")
            skipped_count += 1
            continue

    # Store results
    results.append({
        'filename': base_name_no_ext,
        'iou': iou_score,
        'dice': dice_score,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'tp': tp,
        'fp': fp,
        'fn': fn,
        'tn': tn,
        'gt_size': np.sum(gt_flat) # Store GT object size
    })
    processed_count += 1
    # print(f"    Metrics: IoU={iou_score:.4f}, Dice={dice_score:.4f}, Acc={accuracy:.4f}") # Verbose

print(f"\nFinished processing. Successfully processed {processed_count} pairs, skipped {skipped_count}.")

# --- Analyze and Plot Results ---
if not results:
    print("\nNo results to analyze. Exiting.")
    exit()

# Create a Pandas DataFrame for easier analysis
results_df = pd.DataFrame(results)

print("\n--- Overall Performance Metrics ---")
print(f"Mean IoU:      {results_df['iou'].mean():.4f} (+/- {results_df['iou'].std():.4f})")
print(f"Median IoU:    {results_df['iou'].median():.4f}")
print(f"Mean Dice:     {results_df['dice'].mean():.4f} (+/- {results_df['dice'].std():.4f})")
print(f"Median Dice:   {results_df['dice'].median():.4f}")
print(f"Mean Accuracy: {results_df['accuracy'].mean():.4f} (+/- {results_df['accuracy'].std():.4f})")
print(f"Mean Precision:{results_df['precision'].mean():.4f} (+/- {results_df['precision'].std():.4f})")
print(f"Mean Recall:   {results_df['recall'].mean():.4f} (+/- {results_df['recall'].std():.4f})")

# --- Generate Plots ---
print(f"\nGenerating plots in: {output_plot_dir}")

plt.style.use('seaborn-v0_8-whitegrid') # Use a clean style

# 1. Distribution of IoU Scores
plt.figure(figsize=(10, 6))
sns.histplot(results_df['iou'], bins=20, kde=True)
plt.title('Distribution of IoU Scores', fontsize=16)
plt.xlabel('IoU Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xlim(0, 1)
plt.axvline(results_df['iou'].mean(), color='r', linestyle='--', label=f"Mean: {results_df['iou'].mean():.3f}")
plt.axvline(results_df['iou'].median(), color='g', linestyle=':', label=f"Median: {results_df['iou'].median():.3f}")
plt.legend()
plt.savefig(os.path.join(output_plot_dir, 'iou_distribution.png'), dpi=300)
plt.close()
print("  Saved iou_distribution.png")

# 2. Distribution of Dice Scores
plt.figure(figsize=(10, 6))
sns.histplot(results_df['dice'], bins=20, kde=True)
plt.title('Distribution of Dice Scores', fontsize=16)
plt.xlabel('Dice Score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xlim(0, 1)
plt.axvline(results_df['dice'].mean(), color='r', linestyle='--', label=f"Mean: {results_df['dice'].mean():.3f}")
plt.axvline(results_df['dice'].median(), color='g', linestyle=':', label=f"Median: {results_df['dice'].median():.3f}")
plt.legend()
plt.savefig(os.path.join(output_plot_dir, 'dice_distribution.png'), dpi=300)
plt.close()
print("  Saved dice_distribution.png")

# 3. Box Plot of IoU and Dice Scores
plt.figure(figsize=(8, 6))
sns.boxplot(data=results_df[['iou', 'dice']], palette='pastel')
plt.title('Box Plot of IoU and Dice Scores', fontsize=16)
plt.ylabel('Score', fontsize=12)
plt.ylim(0, 1)
plt.savefig(os.path.join(output_plot_dir, 'iou_dice_boxplot.png'), dpi=300)
plt.close()
print("  Saved iou_dice_boxplot.png")

# 4. Scatter Plot: IoU vs. GT Object Size (if GT size varies)
# Filter out images where GT size is 0 for this plot if many exist
plot_df_size = results_df[results_df['gt_size'] > 0]
if not plot_df_size.empty:
    plt.figure(figsize=(10, 6))
    # Use log scale for size if it varies widely
    use_log_scale = plot_df_size['gt_size'].max() / max(1, plot_df_size['gt_size'].min()) > 100
    ax = sns.scatterplot(x='gt_size', y='iou', data=plot_df_size, alpha=0.6)
    plt.title('IoU Score vs. Ground Truth Object Size', fontsize=16)
    plt.ylabel('IoU Score', fontsize=12)
    plt.xlabel(f'GT Object Size (pixels{" - Log Scale" if use_log_scale else ""})', fontsize=12)
    plt.ylim(0, 1.05)
    if use_log_scale:
        ax.set_xscale('log')
    plt.savefig(os.path.join(output_plot_dir, 'iou_vs_gt_size_scatter.png'), dpi=300)
    plt.close()
    print("  Saved iou_vs_gt_size_scatter.png")
else:
    print("  Skipping IoU vs GT Size plot (no GT objects found or all have size 0).")


# --- Identify Best/Worst Cases ---
print("\n--- Example Cases for Qualitative Review ---")
results_df_sorted_iou = results_df.sort_values(by='iou', ascending=False)

# Best IoU cases
print("\nTop 5 Best Performing Images (by IoU):")
for i, row in results_df_sorted_iou.head(5).iterrows():
    print(f"  - File: {row['filename']}{PRED_EXTENSION}, IoU: {row['iou']:.4f}, Dice: {row['dice']:.4f}")

# Worst IoU cases
print("\nTop 5 Worst Performing Images (by IoU):")
for i, row in results_df_sorted_iou.tail(5).iloc[::-1].iterrows(): # Reverse tail for worst first
    print(f"  - File: {row['filename']}{PRED_EXTENSION}, IoU: {row['iou']:.4f}, Dice: {row['dice']:.4f}")


print("\nEvaluation complete.")
# Out:
# Searching for predicted masks in: /home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks
# Found 733 predicted mask files.
#
# Processing image pairs and calculating metrics...
#   Processing: Pred='2189.png', Expecting GT='2189_mask.png'
#   Processing: Pred='1555.png', Expecting GT='1555_mask.png'
#   Processing: Pred='1497.png', Expecting GT='1497_mask.png'
#   Processing: Pred='213.png', Expecting GT='213_mask.png'
#   Processing: Pred='1534.png', Expecting GT='1534_mask.png'
#   Processing: Pred='1296.png', Expecting GT='1296_mask.png'
#   Processing: Pred='1159.png', Expecting GT='1159_mask.png'
#   Processing: Pred='1060.png', Expecting GT='1060_mask.png'
#   Processing: Pred='2154.png', Expecting GT='2154_mask.png'
#   Processing: Pred='1015.png', Expecting GT='1015_mask.png'
#   Processing: Pred='1054.png', Expecting GT='1054_mask.png'
#   Processing: Pred='1171.png', Expecting GT='1171_mask.png'
#   Processing: Pred='1532.png', Expecting GT='1532_mask.png'
#   Processing: Pred='2223.png', Expecting GT='2223_mask.png'
#   Processing: Pred='1090.png', Expecting GT='1090_mask.png'
#   Processing: Pred='144.png', Expecting GT='144_mask.png'
#   Processing: Pred='2193.png', Expecting GT='2193_mask.png'
#   Processing: Pred='1548.png', Expecting GT='1548_mask.png'
#   Processing: Pred='2274.png', Expecting GT='2274_mask.png'
#   Processing: Pred='1988.png', Expecting GT='1988_mask.png'
#   Processing: Pred='1995.png', Expecting GT='1995_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2078.png', Expecting GT='2078_mask.png'
#   Processing: Pred='2211.png', Expecting GT='2211_mask.png'
#   Processing: Pred='2187.png', Expecting GT='2187_mask.png'
#   Processing: Pred='1295.png', Expecting GT='1295_mask.png'
#   Processing: Pred='1157.png', Expecting GT='1157_mask.png'
#   Processing: Pred='1154.png', Expecting GT='1154_mask.png'
#   Processing: Pred='1169.png', Expecting GT='1169_mask.png'
#   Processing: Pred='1987.png', Expecting GT='1987_mask.png'
#   Processing: Pred='1242.png', Expecting GT='1242_mask.png'
#   Processing: Pred='2261.png', Expecting GT='2261_mask.png'
#   Processing: Pred='1279.png', Expecting GT='1279_mask.png'
#   Processing: Pred='1264.png', Expecting GT='1264_mask.png'
#   Processing: Pred='1344.png', Expecting GT='1344_mask.png'
#   Processing: Pred='1483.png', Expecting GT='1483_mask.png'
#   Processing: Pred='2209.png', Expecting GT='2209_mask.png'
#   Processing: Pred='1612.png', Expecting GT='1612_mask.png'
#   Processing: Pred='2226.png', Expecting GT='2226_mask.png'
#   Processing: Pred='1178.png', Expecting GT='1178_mask.png'
#   Processing: Pred='151.png', Expecting GT='151_mask.png'
#   Processing: Pred='1175.png', Expecting GT='1175_mask.png'
#   Processing: Pred='2231.png', Expecting GT='2231_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2048.png', Expecting GT='2048_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='11.png', Expecting GT='11_mask.png'
#   Processing: Pred='1600.png', Expecting GT='1600_mask.png'
#   Processing: Pred='1285.png', Expecting GT='1285_mask.png'
#   Processing: Pred='1274.png', Expecting GT='1274_mask.png'
#   Processing: Pred='154.png', Expecting GT='154_mask.png'
#   Processing: Pred='1164.png', Expecting GT='1164_mask.png'
#   Processing: Pred='1287.png', Expecting GT='1287_mask.png'
#   Processing: Pred='205.png', Expecting GT='205_mask.png'
#   Processing: Pred='1310.png', Expecting GT='1310_mask.png'
#   Processing: Pred='2050.png', Expecting GT='2050_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1475.png', Expecting GT='1475_mask.png'
#   Processing: Pred='1069.png', Expecting GT='1069_mask.png'
#   Processing: Pred='1580.png', Expecting GT='1580_mask.png'
#   Processing: Pred='1228.png', Expecting GT='1228_mask.png'
#   Processing: Pred='1347.png', Expecting GT='1347_mask.png'
#   Processing: Pred='2038.png', Expecting GT='2038_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1146.png', Expecting GT='1146_mask.png'
#   Processing: Pred='1509.png', Expecting GT='1509_mask.png'
#   Processing: Pred='149.png', Expecting GT='149_mask.png'
#   Processing: Pred='2251.png', Expecting GT='2251_mask.png'
#   Processing: Pred='1200.png', Expecting GT='1200_mask.png'
#   Processing: Pred='1325.png', Expecting GT='1325_mask.png'
#   Processing: Pred='2258.png', Expecting GT='2258_mask.png'
#   Processing: Pred='2217.png', Expecting GT='2217_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='126.png', Expecting GT='126_mask.png'
#   Processing: Pred='1074.png', Expecting GT='1074_mask.png'
#   Processing: Pred='1211.png', Expecting GT='1211_mask.png'
#   Processing: Pred='1572.png', Expecting GT='1572_mask.png'
#   Processing: Pred='2036.png', Expecting GT='2036_mask.png'
#   Processing: Pred='2177.png', Expecting GT='2177_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1978.png', Expecting GT='1978_mask.png'
#   Processing: Pred='2159.png', Expecting GT='2159_mask.png'
#   Processing: Pred='2060.png', Expecting GT='2060_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1233.png', Expecting GT='1233_mask.png'
#   Processing: Pred='1201.png', Expecting GT='1201_mask.png'
#   Processing: Pred='1971.png', Expecting GT='1971_mask.png'
#   Processing: Pred='15.png', Expecting GT='15_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2066.png', Expecting GT='2066_mask.png'
#   Processing: Pred='1495.png', Expecting GT='1495_mask.png'
#   Processing: Pred='1964.png', Expecting GT='1964_mask.png'
#   Processing: Pred='1521.png', Expecting GT='1521_mask.png'
#   Processing: Pred='1415.png', Expecting GT='1415_mask.png'
#   Processing: Pred='2106.png', Expecting GT='2106_mask.png'
#   Processing: Pred='122.png', Expecting GT='122_mask.png'
#   Processing: Pred='2007.png', Expecting GT='2007_mask.png'
#   Processing: Pred='1980.png', Expecting GT='1980_mask.png'
#   Processing: Pred='1430.png', Expecting GT='1430_mask.png'
#   Processing: Pred='1220.png', Expecting GT='1220_mask.png'
#   Processing: Pred='200.png', Expecting GT='200_mask.png'
#   Processing: Pred='1577.png', Expecting GT='1577_mask.png'
mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2093.png', Expecting GT='2093_mask.png'
#   Processing: Pred='1473.png', Expecting GT='1473_mask.png'
#   Processing: Pred='1037.png', Expecting GT='1037_mask.png'
#   Processing: Pred='1160.png', Expecting GT='1160_mask.png'
#   Processing: Pred='1407.png', Expecting GT='1407_mask.png'
#   Processing: Pred='2069.png', Expecting GT='2069_mask.png'
#   Processing: Pred='1302.png', Expecting GT='1302_mask.png'
#   Processing: Pred='1442.png', Expecting GT='1442_mask.png'
#   Processing: Pred='2253.png', Expecting GT='2253_mask.png'
#   Processing: Pred='1091.png', Expecting GT='1091_mask.png'
#   Processing: Pred='2044.png', Expecting GT='2044_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2123.png', Expecting GT='2123_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2114.png', Expecting GT='2114_mask.png'
#   Processing: Pred='2042.png', Expecting GT='2042_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1088.png', Expecting GT='1088_mask.png'
#   Processing: Pred='1597.png', Expecting GT='1597_mask.png'
#   Processing: Pred='1117.png', Expecting GT='1117_mask.png'
#   Processing: Pred='1188.png', Expecting GT='1188_mask.png'
#   Processing: Pred='1067.png', Expecting GT='1067_mask.png'
#   Processing: Pred='1582.png', Expecting GT='1582_mask.png'
#   Processing: Pred='1563.png', Expecting GT='1563_mask.png'
#   Processing: Pred='1374.png', Expecting GT='1374_mask.png'
#   Processing: Pred='1002.png', Expecting GT='1002_mask.png'
#   Processing: Pred='1166.png', Expecting GT='1166_mask.png'
#   Processing: Pred='1236.png', Expecting GT='1236_mask.png'
#   Processing: Pred='2238.png', Expecting GT='2238_mask.png'
#   Processing: Pred='2002.png', Expecting GT='2002_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1183.png', Expecting GT='1183_mask.png'
#   Processing: Pred='1499.png', Expecting GT='1499_mask.png'
#   Processing: Pred='1512.png', Expecting GT='1512_mask.png'
#   Processing: Pred='2055.png', Expecting GT='2055_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1306.png', Expecting GT='1306_mask.png'
#   Processing: Pred='2077.png', Expecting GT='2077_mask.png'
#   Processing: Pred='156.png', Expecting GT='156_mask.png'
#   Processing: Pred='100.png', Expecting GT='100_mask.png'
#   Processing: Pred='2264.png', Expecting GT='2264_mask.png'
#   Processing: Pred='2140.png', Expecting GT='2140_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1320.png', Expecting GT='1320_mask.png'
#   Processing: Pred='1465.png', Expecting GT='1465_mask.png'
#   Processing: Pred='1545.png', Expecting GT='1545_mask.png'
#   Processing: Pred='1618.png', Expecting GT='1618_mask.png'
#   Processing: Pred='2275.png', Expecting GT='2275_mask.png'
#   Processing: Pred='2024.png', Expecting GT='2024_mask.png'
#   Processing: Pred='1020.png', Expecting GT='1020_mask.png'
#   Processing: Pred='1186.png', Expecting GT='1186_mask.png'
#   Processing: Pred='2116.png', Expecting GT='2116_mask.png'
#   Processing: Pred='2144.png', Expecting GT='2144_mask.png'
#   Processing: Pred='1491.png', Expecting GT='1491_mask.png'
#   Processing: Pred='1087.png', Expecting GT='1087_mask.png'
#   Processing: Pred='2280.png', Expecting GT='2280_mask.png'
#   Processing: Pred='1149.png', Expecting GT='1149_mask.png'
#   Processing: Pred='133.png', Expecting GT='133_mask.png'
#   Processing: Pred='2141.png', Expecting GT='2141_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='
mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2202.png', Expecting GT='2202_mask.png'
#   Processing: Pred='1393.png', Expecting GT='1393_mask.png'
#   Processing: Pred='1433.png', Expecting GT='1433_mask.png'
#   Processing: Pred='1312.png', Expecting GT='1312_mask.png'
#   Processing: Pred='1049.png', Expecting GT='1049_mask.png'
#   Processing: Pred='20.png', Expecting GT='20_mask.png'
#   Processing: Pred='2098.png', Expecting GT='2098_mask.png'
#   Processing: Pred='2196.png', Expecting GT='2196_mask.png'
#   Processing: Pred='2198.png', Expecting GT='2198_mask.png'
#   Processing: Pred='1163.png', Expecting GT='1163_mask.png'
#   Processing: Pred='1027.png', Expecting GT='1027_mask.png'
#   Processing: Pred='2121.png', Expecting GT='2121_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2256.png', Expecting GT='2256_mask.png'
#   Processing: Pred='2263.png', Expecting GT='2263_mask.png'
#   Processing: Pred='1421.png', Expecting GT='1421_mask.png'
#   Processing: Pred='1235.png', Expecting GT='1235_mask.png'
#   Processing: Pred='1573.png', Expecting GT='1573_mask.png'
#   Processing: Pred='1277.png', Expecting GT='1277_mask.png'
#   Processing: Pred='1152.png', Expecting GT='1152_mask.png'
#   Processing: Pred='1031.png', Expecting GT='1031_mask.png'
#   Processing: Pred='1109.png', Expecting GT='1109_mask.png'
#   Processing: Pred='1458.png', Expecting GT='1458_mask.png'
#   Processing: Pred='2161.png', Expecting GT='2161_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1113.png', Expecting GT='1113_mask.png'
#   Processing: Pred='1129.png', Expecting GT='1129_mask.png'
#   Processing: Pred='1539.png', Expecting GT='1539_mask.png'
#   Processing: Pred='1111.png', Expecting GT='1111_mask.png'
#   Processing: Pred='2242.png', Expecting GT='2242_mask.png'
#   Processing: Pred='1550.png', Expecting GT='1550_mask.png'
#   Processing: Pred='1448.png', Expecting GT='1448_mask.png'
#   Processing: Pred='1331.png', Expecting GT='1331_mask.png'
#   Processing: Pred='1207.png', Expecting GT='1207_mask.png'
#   Processing: Pred='1608.png', Expecting GT='1608_mask.png'
#   Processing: Pred='1484.png', Expecting GT='1484_mask.png'
#   Processing: Pred='1212.png', Expecting GT='1212_mask.png'
#   Processing: Pred='1194.png', Expecting GT='1194_mask.png'
#   Processing: Pred='1044.png', Expecting GT='1044_mask.png'
#   Processing: Pred='1551.png', Expecting GT='1551_mask.png'
#   Processing: Pred='1383.png', Expecting GT='1383_mask.png'
#   Processing: Pred='1504.png', Expecting GT='1504_mask.png'
#   Processing: Pred='2.png', Expecting GT='2_mask.png'
#   Processing: Pred='1187.png', Expecting GT='1187_mask.png'
#   Processing: Pred='2272.png', Expecting GT='2272_mask.png'
#   Processing: Pred='1356.png', Expecting GT='1356_mask.png'
#   Processing: Pred='134.png', Expecting GT='134_mask.png'
#   Processing: Pred='1389.png', Expecting GT='1389_mask.png'
#   Processing: Pred='1590.png', Expecting GT='1590_mask.png'
#   Processing: Pred='1202.png', Expecting GT='1202_mask.png'
#   Processing: Pred='1380.png', Expecting GT='1380_mask.png'
#   Processing: Pred='2011.png', Expecting GT='2011_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1464.png', Expecting GT='1464_mask.png'
#   Processing: Pred='2143.png', Expecting GT='2143_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1322.png', Expecting GT='1322_mask.png'
#   Processing: Pred='1107.png', Expecting GT='1107_mask.png'
#   Processing: Pred='1436.png', Expecting GT='1436_mask.png'
#   Processing: Pred='1355.png', Expecting GT='1355_mask.png'
#   Processing: Pred='1261.png', Expecting GT='1261_mask.png'
#   Processing: Pred='1016.png', Expecting GT='1016_mask.png'
#   Processing: Pred='1518.png', Expecting GT='1518_mask.png'
#   Processing: Pred='1994.png', Expecting GT='1994_mask.png'
#   Processing: Pred='2107.png', Expecting GT='2107_mask.png'
#   Processing: Pred='131.png', Expecting GT='131_mask.png'
#   Processing: Pred='2182.png', Expecting GT='2182_mask.png'
#   Processing: Pred='1153.png', Expecting GT='1153_mask.png'
#   Processing: Pred='1538.png', Expecting GT='1538_mask.png'
#   Processing: Pred='1141.png', Expecting GT='1141_mask.png'
#   Processing: Pred='1961.png', Expecting GT='1961_mask.png'
#   Processing: Pred='1314.png', Expecting GT='1314_mask.png'
#   Processing: Pred='1376.png', Expecting GT='1376_mask.png'
#   Processing: Pred='1525.png', Expecting GT='1525_mask.png'
#   Processing: Pred='1128.png', Expecting GT='1128_mask.png'
#   Processing: Pred='1168.png', Expecting GT='1168_mask.png'
#   Processing: Pred='16.png', Expecting GT='16_mask.png'
#   Processing: Pred='2218.png', Expecting GT='2218_mask.png'
#   Processing: Pred='2017.png', Expecting GT='2017_mask.png'
#   Processing: Pred='1043.png', Expecting GT='1043_mask.png'
#   Processing: Pred='2148.png', Expecting GT='2148_mask.png'
#   Processing: Pred='1086.png', Expecting GT='1086_mask.png'
#   Processing: Pred='2265.png', Expecting GT='2265_mask.png'
#   Processing: Pred='103.png', Expecting GT='103_mask.png'
#   Processing: Pred='2092.png', Expecting GT='2092_mask.png'
#   Processing: Pred='1990.png', Expecting GT='1990_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1976.png', Expecting GT='1976_mask.png'
#   Processing: Pred='2257.png', Expecting GT='2257_mask.png'
#   Processing: Pred='1575.png', Expecting GT='1575_mask.png'
#   Processing: Pred='1592.png', Expecting GT='1592_mask.png'
#   Processing: Pred='1370.png', Expecting GT='1370_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2237.png', Expecting GT='2237_mask.png'
#   Processing: Pred='207.png', Expecting GT='207_mask.png'
#   Processing: Pred='1134.png', Expecting GT='1134_mask.png'
#   Processing: Pred='224.png', Expecting GT='224_mask.png'
#   Processing: Pred='1343.png', Expecting GT='1343_mask.png'
#   Processing: Pred='1204.png', Expecting GT='1204_mask.png'
#   Processing: Pred='1457.png', Expecting GT='1457_mask.png'
#   Processing: Pred='2026.png', Expecting GT='2026_mask.png'
#   Processing: Pred='2129.png', Expecting GT='2129_mask.png'
#   Processing: Pred='1173.png', Expecting GT='1173_mask.png'
#   Processing: Pred='2100.png', Expecting GT='2100_mask.png'
#   Processing: Pred='1205.png', Expecting GT='1205_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='2241.png', Expecting GT='2241_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred
#   Processing: Pred='1591.png', Expecting GT='1591_mask.png'
#   Processing: Pred='1303.png', Expecting GT='1303_mask.png'
#   Processing: Pred='2079.png', Expecting GT='2079_mask.png'
#   Processing: Pred='120.png', Expecting GT='120_mask.png'
#   Processing: Pred='1076.png', Expecting GT='1076_mask.png'
#   Processing: Pred='140.png', Expecting GT='140_mask.png'
#   Processing: Pred='1165.png', Expecting GT='1165_mask.png'
#   Processing: Pred='1984.png', Expecting GT='1984_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='124.png', Expecting GT='124_mask.png'
#   Processing: Pred='1502.png', Expecting GT='1502_mask.png'
#   Processing: Pred='2186.png', Expecting GT='2186_mask.png'
#   Processing: Pred='1338.png', Expecting GT='1338_mask.png'
#   Processing: Pred='160.png', Expecting GT='160_mask.png'
#   Processing: Pred='222.png', Expecting GT='222_mask.png'
#   Processing: Pred='1595.png', Expecting GT='1595_mask.png'
#   Processing: Pred='1318.png', Expecting GT='1318_mask.png'
#   Processing: Pred='1223.png', Expecting GT='1223_mask.png'
#   Processing: Pred='1386.png', Expecting GT='1386_mask.png'
#   Processing: Pred='2094.png', Expecting GT='2094_mask.png'
#   Processing: Pred='1304.png', Expecting GT='1304_mask.png'
#   Processing: Pred='1470.png', Expecting GT='1470_mask.png'
#   Processing: Pred='1438.png', Expecting GT='1438_mask.png'
#   Processing: Pred='1238.png', Expecting GT='1238_mask.png'
#   Processing: Pred='1397.png', Expecting GT='1397_mask.png'
#   Processing: Pred='1434.png', Expecting GT='1434_mask.png'
#   Processing: Pred='1131.png', Expecting GT='1131_mask.png'
#   Processing: Pred='125.png', Expecting GT='125_mask.png'
#   Processing: Pred='1047.png', Expecting GT='1047_mask.png'
#   Processing: Pred='1487.png', Expecting GT='1487_mask.png'
#   Processing: Pred='1579.png', Expecting GT='1579_mask.png'
#   Processing: Pred='1351.png', Expecting GT='1351_mask.png'
#   Processing: Pred='1492.png', Expecting GT='1492_mask.png'
#   Processing: Pred='2117.png', Expecting GT='2117_mask.png'
#   Processing: Pred='1291.png', Expecting GT='1291_mask.png'
#   Processing: Pred='1278.png', Expecting GT='1278_mask.png'
#   Processing: Pred='2277.png', Expecting GT='2277_mask.png'
#   Processing: Pred='115.png', Expecting GT='115_mask.png'
#   Processing: Pred='1589.png', Expecting GT='1589_mask.png'
#   Processing: Pred='2016.png', Expecting GT='2016_mask.png'
#   Processing: Pred='1208.png', Expecting GT='1208_mask.png'
#   Processing: Pred='1966.png', Expecting GT='1966_mask.png'
#   Processing: Pred='1026.png', Expecting GT='1026_mask.png'
#   Processing: Pred='1010.png', Expecting GT='1010_mask.png'
#   Processing: Pred='1503.png', Expecting GT='1503_mask.png'
#   Processing: Pred='1124.png', Expecting GT='1124_mask.png'
#   Processing: Pred='2045.png', Expecting GT='2045_mask.png'
#   Processing: Pred='2171.png', Expecting GT='2171_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='209.png', Expecting GT='209_mask.png'
#   Processing: Pred='1013.png', Expecting GT='1013_mask.png'
#   Processing: Pred='139.png', Expecting GT='139_mask.png'
#   Processing: Pred='1133.png', Expecting GT='1133_mask.png'
#   Processing: Pred='148.png', Expecting GT='148_mask.png'
#   Processing: Pred='1606.png', Expecting GT='1606_mask.png'
#   Processing: Pred='1571.png', Expecting GT='1571_mask.png'
#   Processing: Pred='1155.png', Expecting GT='1155_mask.png'
#   Processing: Pred='1189.png', Expecting GT='1189_mask.png'
#   Processing: Pred='1307.png', Expecting GT='1307_mask.png'
#   Processing: Pred='135.png', Expecting GT='135_mask.png'
#   Processing: Pred='1158.png', Expecting GT='1158_mask.png'
#   Processing: Pred='1290.png', Expecting GT='1290_mask.png'
#   Processing: Pred='1406.png', Expecting GT='1406_mask.png'
#   Processing: Pred='1450.png', Expecting GT='1450_mask.png'
#   Processing: Pred='1096.png', Expecting GT='1096_mask.png'
#   Processing: Pred='2115.png', Expecting GT='2115_mask.png'
#   Processing: Pred='2236.png', Expecting GT='2236_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1449.png', Expecting GT='1449_mask.png'
#   Processing: Pred='1416.png', Expecting GT='1416_mask.png'
#   Processing: Pred='161.png', Expecting GT='161_mask.png'
#   Processing: Pred='1998.png', Expecting GT='1998_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1365.png', Expecting GT='1365_mask.png'
#   Processing: Pred='1547.png', Expecting GT='1547_mask.png'
#   Processing: Pred='14.png', Expecting GT='14_mask.png'
#   Processing: Pred='2232.png', Expecting GT='2232_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='228.png', Expecting GT='228_mask.png'
#   Processing: Pred='1185.png', Expecting GT='1185_mask.png'
#   Processing: Pred='2005.png', Expecting GT='2005_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1195.png', Expecting GT='1195_mask.png'
#   Processing: Pred='1101.png', Expecting GT='1101_mask.png'
#   Processing: Pred='1476.png', Expecting GT='1476_mask.png'
#   Processing: Pred='2072.png', Expecting GT='2072_mask.png'
#   Processing: Pred='2192.png', Expecting GT='2192_mask.png'
#   Processing: Pred='2271.png', Expecting GT='2271_mask.png'
#   Processing: Pred='1038.png', Expecting GT='1038_mask.png'
#   Processing: Pred='2136.png', Expecting GT='2136_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1507.png', Expecting GT='1507_mask.png'
#   Processing: Pred='1268.png', Expecting GT='1268_mask.png'
#   Processing: Pred='1350.png', Expecting GT='1350_mask.png'
#   Processing: Pred='1369.png', Expecting GT='1369_mask.png'
#   Processing: Pred='2212.png', Expecting GT='2212_mask.png'
#   Processing: Pred='1118.png', Expecting GT='1118_mask.png'
#   Processing: Pred='2267.png', Expecting GT='2267_mask.png'
#   Processing: Pred='2088.png', Expecting GT='2088_mask.png'
#   Processing: Pred='106.png', Expecting GT='106_mask.png'
#   Processing: Pred='1469.png', Expecting GT='1469_mask.png'
#   Processing: Pred='1329.png', Expecting GT='1329_mask.png'
#   Processing: Pred='2086.png', Expecting GT='2086_mask.png'
#   Processing: Pred='2219.png', Expecting GT='2219_mask.png'
#     Note: Predicted mask is empty (all background).
#   Processing: Pred='1029.png', Expecting GT='1029_mask.png'
#   Processing: Pred='1283.png', Expecting GT='1283_mask.png'
#   Processing: Pred='2009.png', Expecting GT='2009_mask.png'
#   Processing: Pred='1969.png', Expecting GT='1969_mask.png'
#   Processing: Pred='1418.png', Expecting GT='1418_mask.png'
#   Processing: Pred='1216.png', Expecting GT='1216_mask.png'
#   Processing: Pred='2087.png', Expecting GT='2087_mask.png'
#   Processing: Pred='1508.png', Expecting GT='1508_mask.png'
#   Processing: Pred='1501.png', Expecting GT='1501_mask.png'
#   Processing: Pred='1381.png', Expecting GT='1381_mask.png'
#   Processing: Pred='147.png', Expecting GT='147_mask.png'
#   Processing: Pred='1254.png', Expecting GT='1254_mask.png'
#   Processing: Pred='1145.png', Expecting GT='1145_mask.png'
#   Processing: Pred='1323.png', Expecting GT='1323_mask.png'
#   Processing: Pred='2188.png', Expecting GT='2188_mask.png'
#   Processing: Pred='2054.png', Expecting GT='2054_mask.png'
#   Processing: Pred='2037.png', Expecting GT='2037_mask.png'
#     Note: Predicted mask is empty (all background).
#
# Finished processing. Successfully processed 733 pairs, skipped 0.
#
# --- Overall Performance Metrics ---
# Mean IoU:      0.2334 (+/- 0.2469)
# Median IoU:    0.1451
# Mean Dice:     0.3165 (+/- 0.3124)
# Median Dice:   0.2534
# Mean Accuracy: 0.9716 (+/- 0.0204)
# Mean Precision:0.5699 (+/- 0.4197)
# Mean Recall:   0.2818 (+/- 0.2831)
#
# Generating plots in: /home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/evaluation_plots_1112
#   Saved iou_distribution.png
#   Saved dice_distribution.png
#   Saved iou_dice_boxplot.png
#   Saved iou_vs_gt_size_scatter.png
#
# --- Example Cases for Qualitative Review ---
#
# Top 5 Best Performing Images (by IoU):
#   - File: 1539.png, IoU: 0.7657, Dice: 0.8673
#   - File: 1028.png, IoU: 0.7383, Dice: 0.8494
#   - File: 1282.png, IoU: 0.7361, Dice: 0.8480
#   - File: 1427.png, IoU: 0.7346, Dice: 0.8470
#   - File: 1186.png, IoU: 0.7271, Dice: 0.8420
#
# Top 5 Worst Performing Images (by IoU):
#   - File: 2037.png, IoU: 0.0000, Dice: 0.0000
#   - File: 2235.png, IoU: 0.0000, Dice: 0.0000
#   - File: 1272.png, IoU: 0.0000, Dice: 0.0000
#   - File: 1486.png, IoU: 0.0000, Dice: 0.0000
#   - File: 1406.png, IoU: 0.0000, Dice: 0.0000
#
# Evaluation complete.

# %% [markdown]
# # Usig GT for analysis

# %% [markdown]
# # SegGPT + GT + Multi GPU

# %%
# %% [markdown]
# # SegGPT Inference Setup (Multi-GPU via Multiprocessing)

# %%
import torch
from PIL import Image, ImageOps, ImageDraw
import matplotlib.pyplot as plt
import numpy as np
from transformers import SegGptImageProcessor, SegGptForImageSegmentation
import os # <-- Added import for os.name check
import glob
import random
import gc
import time
# Import multiprocessing library
import multiprocessing as mp
from math import ceil # For splitting work

# %% [markdown]
# ## 1. Configuration

# %%
# --- Paths ---
# !!! PLEASE VERIFY THESE PATHS ARE CORRECT FOR YOUR SYSTEM !!!
reference_image_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/1_reference_image/images"
reference_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/2_reference_mask_from_OF/masks"
target_image_dir = "/home/sabbbir/Documents/of/Brats_FT/brats/train/images" # Using Brats training images
coco_gt_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/COCO GT/masks" # Verify matching logic

# --- Output ---
# Using common directories - ensure filenames are unique or create worker-specific dirs if needed
output_pred_mask_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks"
output_plot_dir = "/home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/7_output_plots"

# --- Settings ---
MASK_EXTENSION = ".png"
IMAGE_EXTENSIONS = ["*.png", "*.jpg", "*.jpeg"] # Add other extensions if needed for Brats
NUM_GPUS_TO_USE = 2 # How many GPUs you want to utilize
FIXED_REF_INDEX = 1 # Index of the reference pair in valid_ref_pairs to use for all predictions
PLOT_RESULTS = True # Set to False to disable plotting generation (might save memory/time)

# --- Setup COCO GT Usage ---
use_coco_gt = False
# IMPORTANT: Verify GT mask filename matching logic below if enabling this.
if coco_gt_mask_dir and os.path.isdir(coco_gt_mask_dir):
    use_coco_gt = True
    print(f"COCO Ground Truth masks will be attempted from: {coco_gt_mask_dir}")
    print("!!! WARNING: Ensure GT mask filenames match target image base names + '_mask.png' or adjust logic.")
else:
    print("COCO Ground Truth mask directory not provided or invalid. GT masks will not be used.")

# Create output directories if they don't exist
os.makedirs(output_pred_mask_dir, exist_ok=True)
os.makedirs(output_plot_dir, exist_ok=True)
print(f"Output predicted binary masks will be saved to: {output_pred_mask_dir}")
print(f"Output plots (2x3) will be saved to: {output_plot_dir}")


# %% [markdown]
# ## 2. Helper Functions

# %%
# Prepare Colormaps and Colors (once)
ref_overlay_color = np.array([1.0, 1.0, 0.0]) # Yellow for reference examples
ref_overlay_alpha = 0.6
gt_overlay_color = np.array([0.0, 1.0, 0.0]) # Lime Green for GT
gt_overlay_alpha = 0.7
# Define a distinct color for the prediction overlay in the comparison plot
pred_compare_color = np.array([1.0, 0.0, 0.0]) # Red for prediction
pred_compare_alpha = 0.5 # Alpha for prediction overlay

def create_overlay(image_np_float, mask_np, color_rgb, alpha_val):
    """ Overlays a single-color mask onto an image. """
    if image_np_float.shape[:2] != mask_np.shape:
         mask_pil = Image.fromarray(mask_np).resize(image_np_float.shape[:2][::-1], Image.NEAREST)
         mask_np = np.array(mask_pil)
         del mask_pil # Cleanup

    overlay = image_np_float.copy()
    # Ensure mask_np is boolean or 0/1 for alpha calculation
    mask_bool = (mask_np > 0) # Use threshold if mask is not binary (e.g., > 128 for L mode)
    mask_alpha = mask_bool.astype(np.float32) * alpha_val
    mask_color_rgb = np.tile(color_rgb[None, None, :], mask_np.shape + (1,))

    alpha_mask = mask_alpha[:, :, None] # Add channel dim for broadcasting
    overlay = (1 - alpha_mask) * overlay + alpha_mask * mask_color_rgb

    # Cleanup intermediate arrays
    del mask_alpha, mask_color_rgb, alpha_mask, mask_bool
    return np.clip(overlay, 0, 1)

# %% [markdown]
# ## 3. Worker Function (Executed by Each Process)

# %%
def worker_function(worker_id, total_workers, gpu_id, all_target_files, config):
    """
    Main processing function for a single worker process.
    Args:
        worker_id (int): ID of this worker (0-based).
        total_workers (int): Total number of workers.
        gpu_id (int): GPU ID assigned to this worker.
        all_target_files (list): List of all target image file paths.
        config (dict): Dictionary containing configuration paths and settings.
    """
    # --- Assign GPU Environment Variable ---
    # This MUST happen before torch CUDA initialization in this process
    # Handle case where no GPU is assigned (e.g., running on CPU)
    if gpu_id >= 0:
        os.environ['CUDA_VISIBLE_DEVICES'] = str(gpu_id)
        worker_prefix = f"[Worker {worker_id} | GPU {gpu_id}]"
    else:
        os.environ['CUDA_VISIBLE_DEVICES'] = "" # Ensure CUDA isn't accidentally used
        worker_prefix = f"[Worker {worker_id} | CPU]"

    print(f"{worker_prefix}: Process started.")

    # --- Unpack Config ---
    reference_image_dir = config['reference_image_dir']
    reference_mask_dir = config['reference_mask_dir']
    coco_gt_mask_dir = config['coco_gt_mask_dir']
    output_pred_mask_dir = config['output_pred_mask_dir']
    output_plot_dir = config['output_plot_dir']
    MASK_EXTENSION = config['MASK_EXTENSION']
    IMAGE_EXTENSIONS = config['IMAGE_EXTENSIONS']
    use_coco_gt = config['use_coco_gt']
    FIXED_REF_INDEX = config['FIXED_REF_INDEX']
    PLOT_RESULTS = config['PLOT_RESULTS']

    # --- Setup Model and Device ---
    print(f"{worker_prefix}: Loading model, processor, setting up device...")
    try:
        # Verify CUDA is available *after* setting env var
        # Use the assigned gpu_id if it's valid and CUDA is available
        device = "cpu"
        if gpu_id >= 0 and torch.cuda.is_available():
             # Check if the *specific* assigned GPU is visible after setting CUDA_VISIBLE_DEVICES
             # Note: After setting CUDA_VISIBLE_DEVICES=N, GPU N becomes device 'cuda:0' to torch
             if torch.cuda.device_count() > 0:
                 device = "cuda:0" # Always use cuda:0 as it's the only one visible
             else:
                 print(f"{worker_prefix}: WARNING - CUDA available but assigned GPU {gpu_id} not visible/found after setting env var. Using CPU.")
        elif gpu_id >= 0 and not torch.cuda.is_available():
            print(f"{worker_prefix}: WARNING - GPU {gpu_id} assigned, but CUDA not available. Using CPU.")
        else: # gpu_id was < 0
             print(f"{worker_prefix}: Running on CPU.")


        model_name = "BAAI/seggpt-vit-large"
        # Load models fresh in each process
        processor = SegGptImageProcessor.from_pretrained(model_name)
        model = SegGptForImageSegmentation.from_pretrained(model_name)
        model.to(device)
        print(f"{worker_prefix}: Using device: {device}")
    except Exception as e:
        print(f"{worker_prefix}: FATAL ERROR during model setup: {e}")
        return # Exit this worker process if model setup fails

    # --- Find Reference Pairs (Needed to select the fixed one) ---
    worker_all_ref_files = []
    for ext in IMAGE_EXTENSIONS:
        worker_all_ref_files.extend(glob.glob(os.path.join(reference_image_dir, ext)))
    worker_valid_ref_pairs = []
    for ref_img_path in worker_all_ref_files:
        ref_base = os.path.splitext(os.path.basename(ref_img_path))[0]
        # ref_base = os.path.splitext(os.path.basename(ref_img_path))[0]
        ref_mask_path = os.path.join(reference_mask_dir, ref_base + MASK_EXTENSION)
        if os.path.exists(ref_mask_path):
            worker_valid_ref_pairs.append({"image": ref_img_path, "mask": ref_mask_path})
    if not worker_valid_ref_pairs or FIXED_REF_INDEX >= len(worker_valid_ref_pairs):
        print(f"{worker_prefix}: FATAL ERROR - Cannot find enough valid reference pairs or invalid FIXED_REF_INDEX.")
        return
    prediction_ref_pair = worker_valid_ref_pairs[FIXED_REF_INDEX]
    print(f"{worker_prefix}: Using fixed reference pair index {FIXED_REF_INDEX}: Image='{os.path.basename(prediction_ref_pair['image'])}'")

    # --- Load Fixed Reference Pair ONCE ---
    try:
        pred_ref_image = Image.open(prediction_ref_pair['image']).convert("RGB")
        pred_ref_mask = Image.open(prediction_ref_pair['mask']).convert("L")
        if pred_ref_mask.size != pred_ref_image.size:
            pred_ref_mask = pred_ref_mask.resize(pred_ref_image.size, Image.NEAREST)
        print(f"{worker_prefix}: Fixed reference pair loaded.")
    except Exception as e:
        print(f"{worker_prefix}: FATAL ERROR loading fixed reference pair: {e}")
        return

    # --- Load Plotting Reference Data ONCE (Optional based on PLOT_RESULTS) ---
    plot_ref_data = []
    if PLOT_RESULTS:
        num_refs_to_plot = min(len(worker_valid_ref_pairs), 3)
        available_indices = list(range(len(worker_valid_ref_pairs)))
        if FIXED_REF_INDEX in available_indices:
            available_indices.remove(FIXED_REF_INDEX)
        if len(available_indices) >= num_refs_to_plot:
             plot_ref_indices = random.sample(available_indices, k=num_refs_to_plot)
        else: # Not enough other refs, sample from all including fixed ref
             plot_ref_indices = random.sample(range(len(worker_valid_ref_pairs)), k=num_refs_to_plot)

        plot_ref_pairs_info = [worker_valid_ref_pairs[i] for i in plot_ref_indices]
        print(f"{worker_prefix}: Loading {num_refs_to_plot} reference pairs for plotting examples...")
        for i, pair_info in enumerate(plot_ref_pairs_info):
            try:
                ref_img = Image.open(pair_info['image']).convert("RGB")
                ref_mask = Image.open(pair_info['mask']).convert("L")
                if ref_mask.size != ref_img.size:
                    ref_mask = ref_mask.resize(ref_img.size, Image.NEAREST)
                ref_img_np = np.array(ref_img).astype(np.float32) / 255.0
                ref_mask_np = np.array(ref_mask)
                ref_overlay = create_overlay(ref_img_np, ref_mask_np, ref_overlay_color, ref_overlay_alpha)
                plot_ref_data.append({
                    'overlay_np': ref_overlay, 'name': os.path.basename(pair_info['image'])
                })
                del ref_img, ref_mask, ref_img_np, ref_mask_np, ref_overlay # Aggressive cleanup
            except Exception as e:
                print(f"{worker_prefix}: Warning - Error loading plot reference {i}: {e}")
        while len(plot_ref_data) < 3: plot_ref_data.append(None) # Add placeholders


    # --- Determine Workload for this Worker ---
    num_files_total = len(all_target_files)
    num_files_per_worker = ceil(num_files_total / total_workers) # Use ceil for better distribution
    start_index = worker_id * num_files_per_worker
    end_index = min(start_index + num_files_per_worker, num_files_total) # Ensure end_index doesn't exceed total
    target_files_slice = all_target_files[start_index:end_index]

    print(f"{worker_prefix}: Processing images index {start_index} to {end_index-1} ({len(target_files_slice)} files).")

    # --- Main Processing Loop ---
    total_processed_worker = 0
    error_count_worker = 0
    for idx_slice, target_image_path in enumerate(target_files_slice):
        global_idx = start_index + idx_slice # For logging overall progress
        # Define temporary variables scoped to the loop iteration
        target_image = gt_mask_np = inputs = outputs = processed_output = None
        pred_mask = pred_mask_np = comparison_overlay_np = None
        fig = axes = None
        target_image_np_float = None # Ensure defined

        try:
            target_base_filename = os.path.splitext(os.path.basename(target_image_path))[0]
            print("-" * 40)
            print(f"{worker_prefix}: Processing TARGET {global_idx+1}/{num_files_total}: {os.path.basename(target_image_path)}")

            output_pred_mask_filename = os.path.join(output_pred_mask_dir, f"{target_base_filename}.png")
            output_plot_filename = os.path.join(output_plot_dir, f"plot_{target_base_filename}.png")

            # --- 4a. Load Target Image ---
            try:
                target_image = Image.open(target_image_path).convert("RGB")
                target_image_np_float = np.array(target_image).astype(np.float32) / 255.0
            except Exception as e:
                print(f"{worker_prefix}: ERROR loading target image {target_image_path}: {e}. Skipping.")
                error_count_worker += 1
                continue # Skip to next image

            # --- 4a-bis. Load Ground Truth Mask ---
            gt_mask_np = None # Initialize to None for each target
            if use_coco_gt:
                gt_mask_filename = f"{target_base_filename}_mask.png" # Example assumption
                gt_mask_path = os.path.join(coco_gt_mask_dir, gt_mask_filename)
                if os.path.exists(gt_mask_path):
                    try:
                        gt_mask_pil = Image.open(gt_mask_path).convert("L")
                        if gt_mask_pil.size != target_image.size:
                             gt_mask_pil = gt_mask_pil.resize(target_image.size, Image.NEAREST)
                        gt_mask_np_temp = np.array(gt_mask_pil)
                        gt_mask_np = ((gt_mask_np_temp > 128).astype(np.uint8) * 255) # Binarize
                        if not np.any(gt_mask_np): gt_mask_np = None # Treat all-black masks as None
                        del gt_mask_pil, gt_mask_np_temp
                    except Exception as e:
                        print(f"{worker_prefix}: Warning: Error loading/processing GT mask {gt_mask_path}: {e}")
                        gt_mask_np = None


            # --- 4b. Prepare Inputs ---
            try:
                inputs = processor(images=[target_image], prompt_images=[pred_ref_image], prompt_masks=[pred_ref_mask], return_tensors="pt")
                # Send inputs to the correct device for this worker
                inputs = {k: v.to(device) for k, v in inputs.items()}
            except Exception as e:
                 print(f"{worker_prefix}: ERROR during processor input preparation: {e}. Skipping.")
                 error_count_worker += 1
                 del target_image, target_image_np_float
                 if gt_mask_np is not None: del gt_mask_np
                 continue

            # --- 4c. Run Inference ---
            pred_mask = pred_mask_np = None # Ensure reset before inference
            try:
                with torch.no_grad(): outputs = model(**inputs)
                target_sizes = [target_image.size[::-1]] # H, W format
                processed_output = processor.post_process_semantic_segmentation(outputs, target_sizes=target_sizes)

                if isinstance(processed_output, list) and len(processed_output) > 0:
                    mask_data = processed_output[0]
                    if isinstance(mask_data, torch.Tensor):
                        pred_mask_tensor = mask_data.cpu().squeeze()
                        pred_mask_np_interim = (pred_mask_tensor.numpy() > 0.5).astype(np.uint8) * 255
                        pred_mask = Image.fromarray(pred_mask_np_interim, mode='L')
                        pred_mask_np = pred_mask_np_interim
                        del pred_mask_tensor, pred_mask_np_interim
                    elif isinstance(mask_data, Image.Image):
                        pred_mask = mask_data.convert('L')
                        pred_mask_np = np.array(pred_mask)
                    else:
                        print(f"{worker_prefix}: Unexpected mask format in processed_output: {type(mask_data)}")

                del outputs, processed_output, inputs
                if 'mask_data' in locals(): del mask_data
                if 'pred_mask_tensor' in locals(): del pred_mask_tensor

                if pred_mask is None or pred_mask_np is None:
                    print(f"{worker_prefix}: Inference failed to produce a valid mask. Skipping.")
                    error_count_worker += 1
                    del target_image, target_image_np_float
                    if gt_mask_np is not None: del gt_mask_np
                    if device.startswith('cuda'): torch.cuda.empty_cache()
                    continue

            except Exception as e:
                print(f"{worker_prefix}: ERROR during inference or post-processing: {e}")
                error_count_worker += 1
                if 'outputs' in locals(): del outputs
                if 'processed_output' in locals(): del processed_output
                if 'inputs' in locals(): del inputs
                if 'mask_data' in locals(): del mask_data
                if 'pred_mask_tensor' in locals(): del pred_mask_tensor
                if 'pred_mask' in locals(): del pred_mask
                if 'pred_mask_np' in locals(): del pred_mask_np
                del target_image, target_image_np_float
                if gt_mask_np is not None: del gt_mask_np
                if device.startswith('cuda'): torch.cuda.empty_cache()
                continue

            # --- 4d. Save Predicted Mask ---
            try:
                pred_mask.save(output_pred_mask_filename)
            except Exception as e:
                print(f"{worker_prefix}: Warning: Error saving predicted mask {output_pred_mask_filename}: {e}")

            # --- 4e/4e-bis. Create Overlays for Comparison Plot ---
            comparison_overlay_np = None # Initialize
            plot_title_suffix = "" # For the comparison plot title
            try:
                current_overlay = target_image_np_float.copy()
                title_parts = ["Target"]

                if gt_mask_np is not None:
                    current_overlay = create_overlay(current_overlay, gt_mask_np, gt_overlay_color, gt_overlay_alpha)
                    title_parts.append("GT (Lime)")

                if pred_mask_np is not None:
                    current_overlay = create_overlay(current_overlay, pred_mask_np, pred_compare_color, pred_compare_alpha)
                    title_parts.append("Pred (Red)")
                else:
                     print(f"{worker_prefix}: Warning: pred_mask_np is None, cannot overlay prediction for plot.")

                comparison_overlay_np = current_overlay
                plot_title_suffix = " + ".join(title_parts)
                del current_overlay

            except Exception as e:
                print(f"{worker_prefix}: Warning: Error creating comparison overlay: {e}")
                if comparison_overlay_np is None:
                    comparison_overlay_np = target_image_np_float
                    plot_title_suffix = "Target (Overlay Error)"

            # --- 4f. Create and Save Plot (Optional) ---
            if PLOT_RESULTS:
                fig = axes = None
                try:
                    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
                    fig.suptitle(f"Segmentation Result for: {os.path.basename(target_image_path)}\n(Worker {worker_id} | Using Single Ref: {os.path.basename(prediction_ref_pair['image'])})", fontsize=14)

                    # Row 1: Reference Examples
                    for i in range(3):
                        ax = axes[0, i]
                        if i < len(plot_ref_data) and plot_ref_data[i] is not None:
                            ax.imshow(plot_ref_data[i]['overlay_np'])
                            ax.set_title(f"Ref Example {i+1}: {plot_ref_data[i]['name']}")
                        else:
                            ax.set_title(f"Ref Example {i+1}: N/A")
                            ax.set_xticks([]); ax.set_yticks([]); ax.set_facecolor('lightgray')
                        ax.axis('off')

                    # Row 2: Target, Prediction Mask, Comparison Overlay
                    axes[1, 0].imshow(target_image_np_float)
                    axes[1, 0].set_title("Target Image"); axes[1, 0].axis('off')

                    if pred_mask_np is not None:
                        axes[1, 1].imshow(pred_mask_np, cmap='gray', vmin=0, vmax=255)
                        axes[1, 1].set_title("Predicted Mask"); axes[1, 1].axis('off')
                    else:
                        axes[1, 1].set_title("Predicted Mask (Error)"); axes[1, 1].axis('off')
                        axes[1, 1].set_facecolor('lightcoral')

                    axes[1, 2].imshow(comparison_overlay_np)
                    axes[1, 2].set_title(plot_title_suffix); axes[1, 2].axis('off')

                    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
                    plt.savefig(output_plot_filename)
                    plt.close(fig)
                    del fig, axes

                except Exception as plot_save_e:
                    print(f"{worker_prefix}: ERROR during plotting or saving plot: {plot_save_e}")
                    error_count_worker += 1
                    if fig is not None: plt.close(fig)
                    if 'fig' in locals(): del fig
                    if 'axes' in locals(): del axes

            # Increment success counter AFTER potential plotting
            total_processed_worker += 1

        except Exception as outer_e:
            print(f"{worker_prefix}: UNEXPECTED loop ERROR processing target {target_image_path}: {outer_e}")
            error_count_worker += 1
            if 'fig' in locals() and fig is not None: plt.close(fig)

        finally:
            # Cleanup at the end of each loop iteration
            del target_image, gt_mask_np, pred_mask, pred_mask_np
            if 'target_image_np_float' in locals(): del target_image_np_float
            if 'comparison_overlay_np' in locals(): del comparison_overlay_np
            if 'fig' in locals() and fig is not None : del fig
            if 'axes' in locals(): del axes
            collected = gc.collect()
            if device.startswith('cuda'): torch.cuda.empty_cache()


    # --- Worker Finished ---
    print(f"{worker_prefix}: --- Worker Finished ---")
    print(f"{worker_prefix}: Successfully processed {total_processed_worker} images.")
    print(f"{worker_prefix}: Encountered errors on {error_count_worker} images.")
    del model, processor, pred_ref_image, pred_ref_mask, plot_ref_data
    gc.collect()
    if device.startswith('cuda'): torch.cuda.empty_cache()


# %% [markdown]
# ## 4. Main Execution Block (Starts Worker Processes)

# %%
# This block should be executed when you want to run the parallel processing
if __name__ == '__main__': # Important for multiprocessing
    print("--- Main Process: Starting Multi-GPU Inference ---")
    start_time = time.time()

    # --- Check GPU Availability ---
    available_gpus = torch.cuda.device_count()
    print(f"Main Process: Found {available_gpus} available GPUs.")
    if available_gpus == 0:
        print("Main Process: No GPUs found. Consider running on CPU (will be slow).")
        if NUM_GPUS_TO_USE > 1:
            print(f"Main Process: WARNING - Requesting {NUM_GPUS_TO_USE} workers but only CPU available. Will run {NUM_GPUS_TO_USE} processes on CPU.")
    elif available_gpus < NUM_GPUS_TO_USE:
        print(f"Main Process: Warning - Requested {NUM_GPUS_TO_USE} GPUs, but only {available_gpus} available. Using {available_gpus}.")
        NUM_GPUS_TO_USE = available_gpus

    if NUM_GPUS_TO_USE <= 0:
        print("Main Process: No workers to start. Exiting.")
        exit()

    # --- Prepare Data and Config for Workers ---
    print("Main Process: Finding target image files...")
    all_target_image_files = []
    for ext in IMAGE_EXTENSIONS:
        all_target_image_files.extend(glob.glob(os.path.join(target_image_dir, ext)))
    if not all_target_image_files:
        print("Main Process: Error - No target image files found. Exiting.")
        exit()
    print(f"Main Process: Found {len(all_target_image_files)} total target images.")

    all_target_image_files.sort()

    config = {
        'reference_image_dir': reference_image_dir,
        'reference_mask_dir': reference_mask_dir,
        'coco_gt_mask_dir': coco_gt_mask_dir,
        'output_pred_mask_dir': output_pred_mask_dir,
        'output_plot_dir': output_plot_dir,
        'MASK_EXTENSION': MASK_EXTENSION,
        'IMAGE_EXTENSIONS': IMAGE_EXTENSIONS,
        'use_coco_gt': use_coco_gt,
        'FIXED_REF_INDEX': FIXED_REF_INDEX,
        'PLOT_RESULTS': PLOT_RESULTS
    }

    # --- Start Worker Processes ---
    processes = []
    print(f"Main Process: Starting {NUM_GPUS_TO_USE} worker processes...")

    # <<< CHANGE MADE HERE: Attempt to force 'fork' if on Linux/macOS >>>
    # This is a potential workaround if running directly from the terminal still fails
    # due to the environment forcing 'spawn'. 'fork' is generally less safe with CUDA
    # but might resolve the AttributeError if 'spawn' cannot find the function.
    try:
        # Check if on a Unix-like system (Linux, macOS) where 'fork' is available
        if os.name == 'posix':
             # Check if the current start method isn't already 'fork'
             current_method = mp.get_start_method(allow_none=True)
             if current_method != 'fork':
                 mp.set_start_method('fork', force=True)
                 print("Main Process: Explicitly set start method to 'fork' as a workaround.")
             else:
                 print("Main Process: Start method already 'fork'. Using it.")
        else:
             print("Main Process: Not on POSIX system. Using default multiprocessing start method (likely 'spawn' on Windows).")
    except RuntimeError as e:
        print(f"Main Process: Warning - Could not set start method to 'fork': {e}. Using default.")
    except ValueError as e:
         print(f"Main Process: Warning - Start method 'fork' might not be available or already set: {e}. Using default.")
    except Exception as e: # Catch other potential issues
        print(f"Main Process: An unexpected error occurred while setting start method: {e}. Using default.")


    for worker_id in range(NUM_GPUS_TO_USE):
        gpu_id = worker_id if available_gpus > 0 else -1
        process = mp.Process(target=worker_function, args=(
            worker_id,
            NUM_GPUS_TO_USE,
            gpu_id,
            all_target_image_files,
            config
        ))
        processes.append(process)
        process.start()

    # --- Wait for Workers to Finish ---
    print("Main Process: Waiting for worker processes to complete...")
    for process in processes:
        process.join()

    # --- All Done ---
    end_time = time.time()
    total_time = end_time - start_time
    print("-" * 50)
    print(f"Main Process: All workers finished.")
    print(f"Total execution time: {total_time:.2f} seconds ({total_time/60:.2f} minutes)")
    if len(all_target_image_files) > 0 and total_time > 0:
        print(f"Average time per image: {total_time / len(all_target_image_files):.3f} seconds")
    print("-" * 50)
# Out:
# COCO Ground Truth masks will be attempted from: /home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/COCO GT/masks
# !!! WARNING: Ensure GT mask filenames match target image base names + '_mask.png' or adjust logic.
# Output predicted binary masks will be saved to: /home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/5_predicted_masks
# Output plots (2x3) will be saved to: /home/sabbbir/Documents/of/OneFormer/IMPLEMENTATION/2_SegGPT/7_output_plots
# --- Main Process: Starting Multi-GPU Inference ---
# Main Process: Found 2 available GPUs.
# Main Process: Finding target image files...
# Main Process: Found 1502 total target images.
# Main Process: Starting 2 worker processes...
